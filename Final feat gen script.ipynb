# %%
import pandas as pd
import numpy as np
import gc
import matplotlib.pyplot as plt
import seaborn as sns
import string
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import nltk
from nltk.corpus import stopwords
import scipy
import lightgbm as lgb

# %%
gp = pd.read_csv('aggregated_features.csv')

# %%
train = pd.read_csv('data/train.csv', parse_dates=['activation_date'])
test = pd.read_csv('data/test.csv', parse_dates=['activation_date'])

train = train.merge(gp, on='user_id', how='left')
test = test.merge(gp, on='user_id', how='left')

agg_cols = list(gp.columns)[1:]

del gp; gc.collect()

train.head()
# Out:
#         item_id       user_id                 region              city  \
# 0  b912c3c6a6ad  e00f8ff2eaf9   Свердловская область      Екатеринбург
# 1  2dac0150717d  39aeb48f0017      Самарская область            Самара
# 2  ba83aefab5dc  91e2f88dd6e3     Ростовская область    Ростов-на-Дону
# 3  02996f1dd2ea  bf5cccea572d              Татарстан  Набережные Челны
# 4  7c90be56d2ab  ef50846afc0b  Волгоградская область         Волгоград
#
#   parent_category_name               category_name  \
# 0          Личные вещи  Товары для детей и игрушки
# 1      Для дома и дачи           Мебель и интерьер
# 2  Бытовая электроника               Аудио и видео
# 3          Личные вещи  Товары для детей и игрушки
# 4            Транспорт                  Автомобили
#
#                        param_1     param_2 param_3                  title  \
# 0    Постельные принадлежности         NaN     NaN  Кокоби(кокон для сна)
# 1                       Другое         NaN     NaN      Стойка для Одежды
# 2  Видео, DVD и Blu-ray плееры         NaN     NaN         Philips bluray
# 3         Автомобильные кресла         NaN     NaN             Автокресло
# 4                   С пробегом  ВАЗ (LADA)    2110         ВАЗ 2110, 2003
#
#        ...      activation_date  user_type  \
# 0      ...           2017-03-28    Private
# 1      ...           2017-03-26    Private
# 2      ...           2017-03-20    Private
# 3      ...           2017-03-25    Company
# 4      ...           2017-03-16    Private
#
#                                                image image_top_1  \
# 0  d10c7e016e03247a3bf2d13348fe959fe6f436c1caf64c...      1008.0
# 1  79c9392cc51a9c81c6eb91eceb8e552171db39d7142700...       692.0
# 2  b7f250ee3f39e1fedd77c141f273703f4a9be59db4b48a...      3032.0
# 3  e6ef97e0725637ea84e3d203e82dadb43ed3cc0a1c8413...       796.0
# 4  54a687a3a0fc1d68aed99bdaaf551c5c70b761b16fd0a2...      2264.0
#
#   deal_probability avg_days_up_user  avg_times_up_user  med_days_up_user  \
# 0          0.12789         8.000000           2.000000               8.0
# 1          0.00000              NaN                NaN               NaN
# 2          0.43177         4.428571           1.142857               3.0
# 3          0.80323        16.714286           2.642857              18.0
# 4          0.20797              NaN                NaN               NaN
#
#    med_times_up_user  n_user_items
# 0                2.0           2.0
# 1                NaN           NaN
# 2                1.0           9.0
# 3                3.0          32.0
# 4                NaN           NaN
#
# [5 rows x 23 columns]

# %%
train = train.sort_values(['activation_date']).reset_index(drop=True)

# %%
train_index, valid_index = train_test_split(np.arange(len(train)), test_size=0.1, random_state=519)

# %%
train.loc[train_index, 'activation_date'].dt.weekday.value_counts()
# Out:
# 0    207048
# 6    205318
# 1    201131
# 2    196631
# 3    191293
# 4    176527
# 5    175133
# Name: activation_date, dtype: int64

# %%
train.loc[valid_index, 'activation_date'].dt.weekday.value_counts()
# Out:
# 0    23007
# 6    22614
# 1    22289
# 2    21884
# 3    21422
# 4    19599
# 5    19528
# Name: activation_date, dtype: int64

# %%
test.loc[:, 'activation_date'].dt.weekday.value_counts()
# Out:
# 2    81888
# 1    81114
# 0    80191
# 3    77177
# 4    70366
# 6    58909
# 5    58793
# Name: activation_date, dtype: int64

# %% [markdown]
# One more thing about the approach that I haven't mentioned yet is that we will have quite some NaN values because not every ID in `train` and `test` occurs in `train_active` and `test_active`. Let's check how big that problem is.

# %%
train[agg_cols].isnull().any(axis=1).sum() / len(train) * 100
# Out:
# 22.407185198586692

# %%
test[agg_cols].isnull().any(axis=1).sum() / len(test) * 100
# Out:
# 24.354198545348694

# %%
train.isnull().sum(), test.isnull().sum()
# Out:
# (item_id                      0
#  user_id                      0
#  region                       0
#  city                         0
#  parent_category_name         0
#  category_name                0
#  param_1                  61576
#  param_2                 654542
#  param_3                 862565
#  title                        0
#  description             116276
#  price                    85362
#  item_seq_number              0
#  activation_date              0
#  user_type                    0
#  image                   112588
#  image_top_1             112588
#  deal_probability             0
#  avg_days_up_user        336875
#  avg_times_up_user       336875
#  med_days_up_user        336875
#  med_times_up_user       336875
#  n_user_items            336875
#  dtype: int64, item_id                      0
#  user_id                      0
#  region                       0
#  city                         0
#  parent_category_name         0
#  category_name                0
#  param_1                  22910
#  param_2                 233229
#  param_3                 306331
#  title                        0
#  description                  0
#  price                    30585
#  item_seq_number              0
#  activation_date              0
#  user_type                    0
#  image                    42609
#  image_top_1              42609
#  avg_days_up_user        123826
#  avg_times_up_user       123826
#  med_days_up_user        123826
#  med_times_up_user       123826
#  n_user_items            123826
#  dtype: int64)

# %% [markdown]
# We have missing features for 22.41% of train and 24.35% of test data. That's not perfect but certainly acceptable. Onto some more basic feature engineering with ideas from [a great kernel](https://www.kaggle.com/tunguz/bow-meta-text-and-dense-features-lb-0-2241?scriptVersionId=3603709).

# %%
import string

# %%
count = lambda l1,l2: sum([1 for x in l1 if x in l2])


for df in [train, test]:
    df['description'].fillna('unknowndescription', inplace=True)
    df['title'].fillna('unknowntitle', inplace=True)

    df['weekday'] = pd.to_datetime(df['activation_date']).dt.day
    
    for col in ['description', 'title']:
        df['num_words_' + col] = df[col].apply(lambda comment: len(comment.split()))
        df['num_unique_words_' + col] = df[col].apply(lambda comment: len(set(w for w in comment.split())))

    df['words_vs_unique_title'] = df['num_unique_words_title'] / df['num_words_title'] * 100
    df['words_vs_unique_description'] = df['num_unique_words_description'] / df['num_words_description'] * 100
    
    df['city'] = df['region'] + '_' + df['city']
    df['num_desc_punct'] = df['description'].apply(lambda x: count(x, set(string.punctuation)))
    
    for col in agg_cols:
        df[col].fillna(-1, inplace=True)
    
    for col in ['price', 'image_top_1']:
         df[col].fillna(-1, inplace=True)
    df.loc[df.price > 0, 'price'] = np.log1p(df.loc[df.price > 0, 'price'])
    
    for col in ['param_1', 'param_2', 'param_3']:
         df[col].fillna('khwinkaggle', inplace=True)

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\khyeh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
train.head(3)
# Out:
#         item_id       user_id             region                       city  \
# 0  3b896605f03c  9457abfa0ebf  Самарская область   Самарская область_Самара
# 1  c81c34d3aac5  0b161da2b144  Иркутская область   Иркутская область_Братск
# 2  a8ab6225dd06  93d527a1ca66      Пермский край  Пермский край_Краснокамск
#
#   parent_category_name              category_name         param_1  \
# 0          Личные вещи     Детская одежда и обувь   Для мальчиков
# 1  Бытовая электроника                   Телефоны      Аксессуары
# 2          Личные вещи  Одежда, обувь, аксессуары  Женская одежда
#
#           param_2              param_3                   title  \
# 0  Верхняя одежда  86-92 см (1-2 года)       Зимний комбенизон
# 1  Чехлы и плёнки          khwinkaggle     Чехол для айфона 6s
# 2  Верхняя одежда            44–46 (M)  Продам кожанную куртку
#
#         ...       med_times_up_user  n_user_items  weekday  \
# 0       ...                     1.5           5.0       15
# 1       ...                     2.0           2.0       15
# 2       ...                    -1.0          -1.0       15
#
#   num_words_description num_unique_words_description num_words_title  \
# 0                     4                            4               2
# 1                     2                            2               4
# 2                     1                            1               3
#
#    num_unique_words_title  words_vs_unique_title  words_vs_unique_description  \
# 0                       2                  100.0                        100.0
# 1                       4                  100.0                        100.0
# 2                       3                  100.0                        100.0
#
#    num_desc_punct
# 0               0
# 1               0
# 2               0
#
# [3 rows x 31 columns]

# %%
target = 'deal_probability'
predictors = [
    'num_desc_punct', 
    'words_vs_unique_description', 'num_unique_words_description', 'num_unique_words_title', 'num_words_description', 'num_words_title',
    'avg_times_up_user', 'avg_days_up_user', 'n_user_items', 
    'price', 'item_seq_number'
]

categorical = [
    'image_top_1', 'param_1', 'param_2', 'param_3', 
    'city', 'region', 'category_name', 'parent_category_name', 'user_type'
]

predictors = predictors + categorical

# %% [markdown]
# ## User Features

# %%
from copy import deepcopy as cp
col = 'user_id'
user_vc = train[col].append(test[col]).value_counts()
old_user_vc = cp(user_vc)
user_vc = user_vc[user_vc>30]
users = user_vc.index
user_filter = users.isin(train[col]) & users.isin(test[col])

print('Original feature types # = {}, new feature types # = {}'.format(
        len(old_user_vc), pd.Series(user_filter).value_counts()[1]))

print(train.loc[train[col].isin(users[user_filter]), col].value_counts().sort_index())
print(test.loc[test[col].isin(users[user_filter]), col].value_counts().sort_index())
print(train.loc[train[col].isin(users[user_filter]), :].shape[0]/train.shape[0]*100.)
print(test.loc[test[col].isin(users[user_filter]), :].shape[0]/test.shape[0]*100.)
# Out:
# Original feature types # = 1009909, new feature types # = 1206
# 00051c5a5f57     28
# 00179aa3c386     41
# 002fb45acb3f     16
# 004e5c8b2870     19
# 00a25ff400ad     35
# 00c5b94b7a0b     25
# 010f0729f73a     46
# 0153902752ed     12
# 017e9b28eda7     24
# 018ef9eebba0     16
# 0193cd5b7517     31
# 01950439a810     36
# 01adfb9f336f     45
# 01c73e264ee9     11
# 01d2db21def6     51
# 01dd42c9ca6d     40
# 02019da6857a     27
# 0201f4ceb3f6     79
# 03082624a937    396
# 0333e0767abf     54
# 03f616357c02     39
# 047d27fa4473    133
# 048095052e86     43
# 0492af69a4d3     28
# 04d0805871df     39
# 057526b08f9f     44
# 0582d1147bd9     17
# 0601d1e1b0bb     23
# 0615f14167f0     60
# 0665f480fd70     79
#                ...
# f9cf1dabe1d0     80
# fa0d3d9023cb    221
# fab381155b7f     67
# fbc9ad428501     40
# fc0907cb4003     31
# fc34d16e5103    130
# fc39a0d34c08     55
# fc7623fecf00     56
# fca7a7a72a65     28
# fcab302a2470     12
# fcc94ec6517e      6
# fcc9aea60220     33
# fcda5accf7f5     30
# fcdb2e335e4d     31
# fcf1a1645f59     42
# fd390da435b4     21
# fd52446a3213     40
# fd6848741fb6     31
# fd78dee8a8b1     14
# fd843ef55509     29
# fe5bcb70eda1     19
# fe99171555ea     29
# fec4bda6b786     36
# fedb2e57d696     31
# fee3226f5238      5
# feece0049542     52
# ff8e3090a795     33
# ff923105f587     61
# ffc5ef2de2e6     29
# ffec1e14c342     24
# Name: user_id, Length: 1206, dtype: int64
# 00051c5a5f57     10
# 00179aa3c386     20
# 002fb45acb3f     18
# 004e5c8b2870     16
# 00a25ff400ad     19
# 00c5b94b7a0b      7
# 010f0729f73a      3
# 0153902752ed     45
# 017e9b28eda7     10
# 018ef9eebba0     16
# 0193cd5b7517     47
# 01950439a810      3
# 01adfb9f336f      5
# 01c73e264ee9     36
# 01d2db21def6     22
# 01dd42c9ca6d      5
# 02019da6857a      6
# 0201f4ceb3f6     23
# 03082624a937      4
# 0333e0767abf     30
# 03f616357c02     57
# 047d27fa4473      3
# 048095052e86     13
# 0492af69a4d3     12
# 04d0805871df      2
# 057526b08f9f      1
# 0582d1147bd9     15
# 0601d1e1b0bb      8
# 0615f14167f0      7
# 0665f480fd70      2
#                ...
# f9cf1dabe1d0      7
# fa0d3d9023cb    158
# fab381155b7f     17
# fbc9ad428501      6
# fc0907cb4003     22
# fc34d16e5103     85
# fc39a0d34c08      7
# fc7623fecf00      4
# fca7a7a72a65     17
# fcab302a2470     36
# fcc94ec6517e     38
# fcc9aea60220      9
# fcda5accf7f5     19
# fcdb2e335e4d      2
# fcf1a1645f59     18
# fd390da435b4     14
# fd52446a3213     10
# fd6848741fb6     33
# fd78dee8a8b1     20
# fd843ef55509      9
# fe5bcb70eda1     12
# fe99171555ea     19
# fec4bda6b786      3
# fedb2e57d696      1
# fee3226f5238    171
# feece0049542     16
# ff8e3090a795      2
# ff923105f587     28
# ffc5ef2de2e6      2
# ffec1e14c342     19
# Name: user_id, Length: 1206, dtype: int64
# 5.23804329317611
# 6.235175183601541

# %%
train.loc[~train[col].isin(users[user_filter]), col] = 'others_users'
test.loc[~test[col].isin(users[user_filter]), col] = 'others_users'

# %%
gp = train.groupby('user_id')

# %%
for col in ['price', 'item_seq_number', 'num_desc_punct']:
    mean_mapping, std_mapping = gp[col].mean(), gp[col].std()
    
    train.loc[:, col+'_user_mean'] = train['user_id'].map(mean_mapping).fillna(0.)
    test.loc[:, col+'_user_mean'] = test['user_id'].map(mean_mapping).fillna(0.)
    
    train.loc[:, col+'_user_std'] = train['user_id'].map(std_mapping).fillna(0.)
    test.loc[:, col+'_user_std'] = test['user_id'].map(std_mapping).fillna(0.)
    
    predictors.extend([col+'_user_mean', col+'_user_std'])
    print(col+' processed')
# Out:
# price processed
# item_seq_number processed
# num_desc_punct processed

# %%
train.isnull().sum(), '\n', test.isnull().sum()
# Out:
# (item_id                              0
#  user_id                              0
#  region                               0
#  city                                 0
#  parent_category_name                 0
#  category_name                        0
#  param_1                              0
#  param_2                              0
#  param_3                              0
#  title                                0
#  description                          0
#  price                                0
#  item_seq_number                      0
#  activation_date                      0
#  user_type                            0
#  image                           112588
#  image_top_1                          0
#  deal_probability                     0
#  avg_days_up_user                     0
#  avg_times_up_user                    0
#  med_days_up_user                     0
#  med_times_up_user                    0
#  n_user_items                         0
#  weekday                              0
#  num_words_description                0
#  num_unique_words_description         0
#  num_words_title                      0
#  num_unique_words_title               0
#  words_vs_unique_title                0
#  words_vs_unique_description          0
#  num_desc_punct                       0
#  price_user_mean                      0
#  price_user_std                       0
#  item_seq_number_user_mean            0
#  item_seq_number_user_std             0
#  num_desc_punct_user_mean             0
#  num_desc_punct_user_std              0
#  dtype: int64, '\n', item_id                             0
#  user_id                             0
#  region                              0
#  city                                0
#  parent_category_name                0
#  category_name                       0
#  param_1                             0
#  param_2                             0
#  param_3                             0
#  title                               0
#  description                         0
#  price                               0
#  item_seq_number                     0
#  activation_date                     0
#  user_type                           0
#  image                           42609
#  image_top_1                         0
#  avg_days_up_user                    0
#  avg_times_up_user                   0
#  med_days_up_user                    0
#  med_times_up_user                   0
#  n_user_items                        0
#  weekday                             0
#  num_words_description               0
#  num_unique_words_description        0
#  num_words_title                     0
#  num_unique_words_title              0
#  words_vs_unique_title               0
#  words_vs_unique_description         0
#  num_desc_punct                      0
#  price_user_mean                     0
#  price_user_std                      0
#  item_seq_number_user_mean           0
#  item_seq_number_user_std            0
#  num_desc_punct_user_mean            0
#  num_desc_punct_user_std             0
#  dtype: int64)

# %%
for col in categorical:
    type_cnt = gp[col].apply(lambda x: len(set(x)))
    train.loc[:, col+'_user_type_cnt'] = train['user_id'].map(type_cnt).fillna(0.)
    test.loc[:, col+'_user_type_cnt'] = test['user_id'].map(type_cnt).fillna(0.)
    predictors.append(col+'_user_type_cnt')
    print(col+' processed')
# Out:
# image_top_1 processed
# param_1 processed
# param_2 processed
# param_3 processed
# city processed
# region processed
# category_name processed
# parent_category_name processed
# user_type processed

# %%
del gp; gc.collect()
# Out:
# 418

# %%
from sklearn.model_selection import KFold
fold_num = 10
kf = KFold(fold_num, shuffle=True, random_state=613451)

mean_enc_cols = ['user_id']

for col in mean_enc_cols:    
    
    train.loc[:, col+'_dp_mean_enc'] = np.zeros((train.shape[0],))
    train.loc[:, col+'_dp_std_enc'] = np.zeros((train.shape[0],))
    test.loc[:, col+'_dp_mean_enc'] = np.zeros((test.shape[0],))
    test.loc[:, col+'_dp_std_enc'] = np.zeros((test.shape[0],))
    
    for train_ix, val_ix in kf.split(train):
        tr_X = train.loc[train_ix, :]
    
        gp = tr_X.groupby(col)['deal_probability']
        mapping, mapping_std = gp.mean(), gp.std()
        
        train.loc[val_ix, col+'_dp_mean_enc'] = train.loc[val_ix, col].map(mapping).fillna(0.)
        train.loc[val_ix, col+'_dp_std_enc'] = train.loc[val_ix, col].map(mapping_std).fillna(0.)
        
        test.loc[:, col+'_dp_mean_enc'] += test.loc[:, col].map(mapping).fillna(0.)
        test.loc[:, col+'_dp_std_enc'] += test.loc[:, col].map(mapping_std).fillna(0.)
     
        del gp
        
    test.loc[:, col+'_dp_mean_enc'] /= fold_num
    test.loc[:, col+'_dp_std_enc'] /= fold_num
    print(col + ' processed.')
    predictors.extend([col+'_dp_mean_enc', col+'_dp_std_enc'])
# Out:
# user_id processed.

# %%
train.isnull().sum(), '\n', test.isnull().sum()
# Out:
# (item_id                                    0
#  user_id                                    0
#  region                                     0
#  city                                       0
#  parent_category_name                       0
#  category_name                              0
#  param_1                                    0
#  param_2                                    0
#  param_3                                    0
#  title                                      0
#  description                                0
#  price                                      0
#  item_seq_number                            0
#  activation_date                            0
#  user_type                                  0
#  image                                 112588
#  image_top_1                                0
#  deal_probability                           0
#  avg_days_up_user                           0
#  avg_times_up_user                          0
#  med_days_up_user                           0
#  med_times_up_user                          0
#  n_user_items                               0
#  weekday                                    0
#  num_words_description                      0
#  num_unique_words_description               0
#  num_words_title                            0
#  num_unique_words_title                     0
#  words_vs_unique_title                      0
#  words_vs_unique_description                0
#  num_desc_punct                             0
#  price_user_mean                            0
#  price_user_std                             0
#  item_seq_number_user_mean                  0
#  item_seq_number_user_std                   0
#  num_desc_punct_user_mean                   0
#  num_desc_punct_user_std                    0
#  image_top_1_user_type_cnt                  0
#  param_1_user_type_cnt                      0
#  param_2_user_type_cnt                      0
#  param_3_user_type_cnt                      0
#  city_user_type_cnt                         0
#  region_user_type_cnt                       0
#  category_name_user_type_cnt                0
#  parent_category_name_user_type_cnt         0
#  user_type_user_type_cnt                    0
#  user_id_dp_mean_enc                        0
#  user_id_dp_std_enc                         0
#  dtype: int64, '\n', item_id                                   0
#  user_id                                   0
#  region                                    0
#  city                                      0
#  parent_category_name                      0
#  category_name                             0
#  param_1                                   0
#  param_2                                   0
#  param_3                                   0
#  title                                     0
#  description                               0
#  price                                     0
#  item_seq_number                           0
#  activation_date                           0
#  user_type                                 0
#  image                                 42609
#  image_top_1                               0
#  avg_days_up_user                          0
#  avg_times_up_user                         0
#  med_days_up_user                          0
#  med_times_up_user                         0
#  n_user_items                              0
#  weekday                                   0
#  num_words_description                     0
#  num_unique_words_description              0
#  num_words_title                           0
#  num_unique_words_title                    0
#  words_vs_unique_title                     0
#  words_vs_unique_description               0
#  num_desc_punct                            0
#  price_user_mean                           0
#  price_user_std                            0
#  item_seq_number_user_mean                 0
#  item_seq_number_user_std                  0
#  num_desc_punct_user_mean                  0
#  num_desc_punct_user_std                   0
#  image_top_1_user_type_cnt                 0
#  param_1_user_type_cnt                     0
#  param_2_user_type_cnt                     0
#  param_3_user_type_cnt                     0
#  city_user_type_cnt                        0
#  region_user_type_cnt                      0
#  category_name_user_type_cnt               0
#  parent_category_name_user_type_cnt        0
#  user_type_user_type_cnt                   0
#  user_id_dp_mean_enc                       0
#  user_id_dp_std_enc                        0
#  dtype: int64)

# %% [markdown]
# ## Text Features

# %%
count_vectorizer_title = CountVectorizer(stop_words=stopwords.words('russian'), lowercase=True, min_df=25)

title_counts = count_vectorizer_title.fit_transform(train['title'].append(test['title']))

train_title_counts = title_counts[:len(train)]
test_title_counts = title_counts[len(train):]


count_vectorizer_desc = TfidfVectorizer(stop_words=stopwords.words('russian'), 
                                        lowercase=True, ngram_range=(1, 2),
                                        max_features=15000)

desc_counts = count_vectorizer_desc.fit_transform(train['description'].append(test['description']))

train_desc_counts = desc_counts[:len(train)]
test_desc_counts = desc_counts[len(train):]

train_title_counts.shape, train_desc_counts.shape
# Out:
# ((1503424, 16447), (1503424, 15000))

# %% [markdown]
# ## Encode Categorical Features

# %%
for feature in categorical:
    print(f'Transforming {feature}...')
    encoder = LabelEncoder()
    encoder.fit(train[feature].append(test[feature]).astype(str))
    
    train[feature] = encoder.transform(train[feature].astype(str))
    test[feature] = encoder.transform(test[feature].astype(str))
# Out:
# Transforming image_top_1...
# Transforming param_1...
# Transforming param_2...
# Transforming param_3...
# Transforming city...
# Transforming region...
# Transforming category_name...
# Transforming parent_category_name...
# Transforming user_type...

# %% [markdown]
# ## Mean Encodings

# %%
for feature in categorical:
    gp = train.groupby(feature)[feature].count()
    train.loc[:, feature+'_cnt'] = train[feature].map(gp).fillna(0.)
    test.loc[:, feature+'_cnt'] = test[feature].map(gp).fillna(0.)
    predictors.append(feature+'_cnt')

# %%
from sklearn.model_selection import KFold
fold_num = 10
kf = KFold(fold_num, shuffle=True, random_state=411519719)

mean_enc_cols = ['item_seq_number']
mean_enc_cols.extend(categorical)

for col in mean_enc_cols:    
    
    train.loc[:, col+'_dp_mean_enc'] = np.zeros((train.shape[0],))
    train.loc[:, col+'_dp_std_enc'] = np.zeros((train.shape[0],))
    test.loc[:, col+'_dp_mean_enc'] = np.zeros((test.shape[0],))
    test.loc[:, col+'_dp_std_enc'] = np.zeros((test.shape[0],))
    
    for train_ix, val_ix in kf.split(train):
        tr_X = train.loc[train_ix, :]
    
        gp = tr_X.groupby(col)['deal_probability']
        mapping, mapping_std = gp.mean(), gp.std()
        
        train.loc[val_ix, col+'_dp_mean_enc'] = train.loc[val_ix, col].map(mapping).fillna(0.)
        train.loc[val_ix, col+'_dp_std_enc'] = train.loc[val_ix, col].map(mapping_std).fillna(0.)
        
        test.loc[:, col+'_dp_mean_enc'] += test.loc[:, col].map(mapping).fillna(0.)
        test.loc[:, col+'_dp_std_enc'] += test.loc[:, col].map(mapping_std).fillna(0.)
     
        del gp
        
    test.loc[:, col+'_dp_mean_enc'] /= fold_num
    test.loc[:, col+'_dp_std_enc'] /= fold_num
    print(col + ' processed.')
    predictors.extend([col+'_dp_mean_enc', col+'_dp_std_enc'])
# Out:
# item_seq_number processed.
# image_top_1 processed.
# param_1 processed.
# param_2 processed.
# param_3 processed.
# city processed.
# region processed.
# category_name processed.
# parent_category_name processed.
# user_type processed.

# %%
train.isnull().sum(), '\n', test.isnull().sum()
# Out:
# (item_id                                  0
#  user_id                                  0
#  region                                   0
#  city                                     0
#  parent_category_name                     0
#  category_name                            0
#  param_1                                  0
#  param_2                                  0
#  param_3                                  0
#  title                                    0
#  description                              0
#  price                                    0
#  item_seq_number                          0
#  activation_date                          0
#  user_type                                0
#  image                               112588
#  image_top_1                              0
#  deal_probability                         0
#  avg_days_up_user                         0
#  avg_times_up_user                        0
#  med_days_up_user                         0
#  med_times_up_user                        0
#  n_user_items                             0
#  weekday                                  0
#  num_words_description                    0
#  num_unique_words_description             0
#  num_words_title                          0
#  num_unique_words_title                   0
#  words_vs_unique_title                    0
#  words_vs_unique_description              0
#                                       ...
#  user_id_dp_std_enc                       0
#  image_top_1_cnt                          0
#  param_1_cnt                              0
#  param_2_cnt                              0
#  param_3_cnt                              0
#  city_cnt                                 0
#  region_cnt                               0
#  category_name_cnt                        0
#  parent_category_name_cnt                 0
#  user_type_cnt                            0
#  item_seq_number_dp_mean_enc              0
#  item_seq_number_dp_std_enc               0
#  image_top_1_dp_mean_enc                  0
#  image_top_1_dp_std_enc                   0
#  param_1_dp_mean_enc                      0
#  param_1_dp_std_enc                       0
#  param_2_dp_mean_enc                      0
#  param_2_dp_std_enc                       0
#  param_3_dp_mean_enc                      0
#  param_3_dp_std_enc                       0
#  city_dp_mean_enc                         0
#  city_dp_std_enc                          0
#  region_dp_mean_enc                       0
#  region_dp_std_enc                        0
#  category_name_dp_mean_enc                0
#  category_name_dp_std_enc                 0
#  parent_category_name_dp_mean_enc         0
#  parent_category_name_dp_std_enc          0
#  user_type_dp_mean_enc                    0
#  user_type_dp_std_enc                     0
#  Length: 77, dtype: int64, '\n', item_id                                 0
#  user_id                                 0
#  region                                  0
#  city                                    0
#  parent_category_name                    0
#  category_name                           0
#  param_1                                 0
#  param_2                                 0
#  param_3                                 0
#  title                                   0
#  description                             0
#  price                                   0
#  item_seq_number                         0
#  activation_date                         0
#  user_type                               0
#  image                               42609
#  image_top_1                             0
#  avg_days_up_user                        0
#  avg_times_up_user                       0
#  med_days_up_user                        0
#  med_times_up_user                       0
#  n_user_items                            0
#  weekday                                 0
#  num_words_description                   0
#  num_unique_words_description            0
#  num_words_title                         0
#  num_unique_words_title                  0
#  words_vs_unique_title                   0
#  words_vs_unique_description             0
#  num_desc_punct                          0
#                                      ...
#  user_id_dp_std_enc                      0
#  image_top_1_cnt                         0
#  param_1_cnt                             0
#  param_2_cnt                             0
#  param_3_cnt                             0
#  city_cnt                                0
#  region_cnt                              0
#  category_name_cnt                       0
#  parent_category_name_cnt                0
#  user_type_cnt                           0
#  item_seq_number_dp_mean_enc             0
#  item_seq_number_dp_std_enc              0
#  image_top_1_dp_mean_enc                 0
#  image_top_1_dp_std_enc                  0
#  param_1_dp_mean_enc                     0
#  param_1_dp_std_enc                      0
#  param_2_dp_mean_enc                     0
#  param_2_dp_std_enc                      0
#  param_3_dp_mean_enc                     0
#  param_3_dp_std_enc                      0
#  city_dp_mean_enc                        0
#  city_dp_std_enc                         0
#  region_dp_mean_enc                      0
#  region_dp_std_enc                       0
#  category_name_dp_mean_enc               0
#  category_name_dp_std_enc                0
#  parent_category_name_dp_mean_enc        0
#  parent_category_name_dp_std_enc         0
#  user_type_dp_mean_enc                   0
#  user_type_dp_std_enc                    0
#  Length: 76, dtype: int64)

# %%
#train.drop(['image_top_1'], axis=1, inplace=True)
#test.drop(['image_top_1'], axis=1, inplace=True)

# %%
x_test = scipy.sparse.hstack([
    test_desc_counts,
    test_title_counts,
    test.loc[:, predictors]
], format='csr')

# %%
x_train = scipy.sparse.hstack([
        train_desc_counts,
        train_title_counts,
        train.loc[:, predictors]
    ], format='csr')
y_train = train.loc[:, target].values

# %%
import pickle

with open('train_features', 'wb') as handle:
    pickle.dump(x_train, handle, protocol=pickle.HIGHEST_PROTOCOL)
    
with open('test_features', 'wb') as handle:
    pickle.dump(x_test, handle, protocol=pickle.HIGHEST_PROTOCOL)
    
with open('train_text_features', 'wb') as handle:
    pickle.dump(train_desc_counts, handle, protocol=pickle.HIGHEST_PROTOCOL)
    
with open('test_text_features', 'wb') as handle:
    pickle.dump(test_desc_counts, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
norm_cols = [col for col in predictors if col not in categorical]
ohe_cols = categorical

norm_cols, ohe_cols
# Out:
# (['num_desc_punct',
#   'words_vs_unique_description',
#   'num_unique_words_description',
#   'num_unique_words_title',
#   'num_words_description',
#   'num_words_title',
#   'avg_times_up_user',
#   'avg_days_up_user',
#   'n_user_items',
#   'price',
#   'item_seq_number',
#   'price_user_mean',
#   'price_user_std',
#   'item_seq_number_user_mean',
#   'item_seq_number_user_std',
#   'num_desc_punct_user_mean',
#   'num_desc_punct_user_std',
#   'image_top_1_user_type_cnt',
#   'param_1_user_type_cnt',
#   'param_2_user_type_cnt',
#   'param_3_user_type_cnt',
#   'city_user_type_cnt',
#   'region_user_type_cnt',
#   'category_name_user_type_cnt',
#   'parent_category_name_user_type_cnt',
#   'user_type_user_type_cnt',
#   'user_id_dp_mean_enc',
#   'user_id_dp_std_enc',
#   'image_top_1_cnt',
#   'param_1_cnt',
#   'param_2_cnt',
#   'param_3_cnt',
#   'city_cnt',
#   'region_cnt',
#   'category_name_cnt',
#   'parent_category_name_cnt',
#   'user_type_cnt',
#   'item_seq_number_dp_mean_enc',
#   'item_seq_number_dp_std_enc',
#   'image_top_1_dp_mean_enc',
#   'image_top_1_dp_std_enc',
#   'param_1_dp_mean_enc',
#   'param_1_dp_std_enc',
#   'param_2_dp_mean_enc',
#   'param_2_dp_std_enc',
#   'param_3_dp_mean_enc',
#   'param_3_dp_std_enc',
#   'city_dp_mean_enc',
#   'city_dp_std_enc',
#   'region_dp_mean_enc',
#   'region_dp_std_enc',
#   'category_name_dp_mean_enc',
#   'category_name_dp_std_enc',
#   'parent_category_name_dp_mean_enc',
#   'parent_category_name_dp_std_enc',
#   'user_type_dp_mean_enc',
#   'user_type_dp_std_enc'],
#  ['image_top_1',
#   'param_1',
#   'param_2',
#   'param_3',
#   'city',
#   'region',
#   'category_name',
#   'parent_category_name',
#   'user_type'])

# %%
all_df = pd.concat([train.loc[:, predictors], test.loc[:, predictors]]).reset_index(drop=True)

# %%
all_df.isnull().sum().max()
# Out:
# 0

# %%
from scipy.stats import boxcox

for c in norm_cols:
    val = all_df.loc[all_df[c]>=0, c]
    
    val = (val-val.min())/(val.max()-val.min())
    val, ld = boxcox(val+1e-15)
    all_df.loc[all_df[c]>=0, c] = (val-val.min())/(val.max()-val.min())
    all_df.loc[all_df[c]<0, c] = -1
    
    print('Column {} transformed with optimal lambda value={}'.format(c, ld))
    del val; gc.collect()
# Out:
# Column num_desc_punct transformed with optimal lambda value=0.16754973532037323
# Column words_vs_unique_description transformed with optimal lambda value=15.273487501374978
# Column num_unique_words_description transformed with optimal lambda value=0.21742276934084376
# Column num_unique_words_title transformed with optimal lambda value=0.17827997754465894
# Column num_words_description transformed with optimal lambda value=0.20976086495103724
# Column num_words_title transformed with optimal lambda value=0.17868148305068648
# Column avg_times_up_user transformed with optimal lambda value=0.10044560216572643
# Column avg_days_up_user transformed with optimal lambda value=1.0193498930825309
# Column n_user_items transformed with optimal lambda value=0.14118194110456056
# Column price transformed with optimal lambda value=0.5225520525538597
# Column item_seq_number transformed with optimal lambda value=0.12441496162322882
# Column price_user_mean transformed with optimal lambda value=0.19602598325930568
# Column price_user_std transformed with optimal lambda value=2.499891710162939
# Column item_seq_number_user_mean transformed with optimal lambda value=-0.046460596398260494
# Column item_seq_number_user_std transformed with optimal lambda value=5.231693047371863
# Column num_desc_punct_user_mean transformed with optimal lambda value=0.04297241723025423
# Column num_desc_punct_user_std transformed with optimal lambda value=0.4936251776650483
# Column image_top_1_user_type_cnt transformed with optimal lambda value=3.6552369755686924
# Column param_1_user_type_cnt transformed with optimal lambda value=1.3475748585082152
# Column param_2_user_type_cnt transformed with optimal lambda value=1.3731852920258734
# Column param_3_user_type_cnt transformed with optimal lambda value=0.8737633607118205
# Column city_user_type_cnt transformed with optimal lambda value=0.671413029687907
# Column region_user_type_cnt transformed with optimal lambda value=0.5550414803215367
# Column category_name_user_type_cnt transformed with optimal lambda value=1.4257547422651133
# Column parent_category_name_user_type_cnt transformed with optimal lambda value=0.6973833540072377
# Column user_type_user_type_cnt transformed with optimal lambda value=0.527372592209298
# Column user_id_dp_mean_enc transformed with optimal lambda value=1.0845672799726935
# Column user_id_dp_std_enc transformed with optimal lambda value=2.1189760472144408
# Column image_top_1_cnt transformed with optimal lambda value=-0.06970610119535188
# Column param_1_cnt transformed with optimal lambda value=0.21966304281940685
# Column param_2_cnt transformed with optimal lambda value=0.2799001092293848
# Column param_3_cnt transformed with optimal lambda value=0.2885978215909504
# Column city_cnt transformed with optimal lambda value=0.48826518910695577
# Column region_cnt transformed with optimal lambda value=0.3210647989043688
# Column category_name_cnt transformed with optimal lambda value=0.23705447218109105
# Column parent_category_name_cnt transformed with optimal lambda value=0.28951000316899966
# Column user_type_cnt transformed with optimal lambda value=0.34902702181016554
# Column item_seq_number_dp_mean_enc transformed with optimal lambda value=0.6728867697435401
# Column item_seq_number_dp_std_enc transformed with optimal lambda value=1.025579962025566
# Column image_top_1_dp_mean_enc transformed with optimal lambda value=0.28967255917002493
# Column image_top_1_dp_std_enc transformed with optimal lambda value=0.8260057617655474
# Column param_1_dp_mean_enc transformed with optimal lambda value=0.045021489786932926
# Column param_1_dp_std_enc transformed with optimal lambda value=0.2118058513308064
# Column param_2_dp_mean_enc transformed with optimal lambda value=0.27561781203479785
# Column param_2_dp_std_enc transformed with optimal lambda value=1.3751053113100857
# Column param_3_dp_mean_enc transformed with optimal lambda value=0.7279187206884932
# Column param_3_dp_std_enc transformed with optimal lambda value=2.8526846970217528
# Column city_dp_mean_enc transformed with optimal lambda value=0.662967426034836
# Column city_dp_std_enc transformed with optimal lambda value=3.374194159310083
# Column region_dp_mean_enc transformed with optimal lambda value=0.9356966553661156
# Column region_dp_std_enc transformed with optimal lambda value=1.0652373742259507
# Column category_name_dp_mean_enc transformed with optimal lambda value=0.2740775881968616
# Column category_name_dp_std_enc transformed with optimal lambda value=0.2934778461031075
# Column parent_category_name_dp_mean_enc transformed with optimal lambda value=0.13255010240317974
# Column parent_category_name_dp_std_enc transformed with optimal lambda value=0.3222084777149351
# Column user_type_dp_mean_enc transformed with optimal lambda value=1.5417960626095777
# Column user_type_dp_std_enc transformed with optimal lambda value=1.8075931452945706

# %%
column_filt = all_df.loc[:, predictors].columns.isin(ohe_cols)
pd.Series(column_filt).value_counts()
# Out:
# False    57
# True      9
# dtype: int64

# %%
from scipy.sparse import csr_matrix
from sklearn.preprocessing import OneHotEncoder
ohe_features = csr_matrix(OneHotEncoder(categorical_features=column_filt).fit_transform(all_df.loc[:, predictors]))
del all_df; gc.collect()
# Out:
# 48

# %%
x_train_ohe_norm = scipy.sparse.hstack([
                        train_desc_counts,
                        train_title_counts,
                        ohe_features[:train.shape[0], :]
                    ], format='csr')

# %%
x_test_ohe_norm = scipy.sparse.hstack([
                        test_desc_counts,
                        test_title_counts,
                        ohe_features[train.shape[0]:, :]
                    ], format='csr')

# %%
with open('train_ohe_norm_features', 'wb') as handle:
    pickle.dump(x_train_ohe_norm, handle, protocol=pickle.HIGHEST_PROTOCOL)
    
with open('test_ohe_norm_features', 'wb') as handle:
    pickle.dump(x_test_ohe_norm, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
feature_names = np.hstack([
    count_vectorizer_desc.get_feature_names(),
    count_vectorizer_title.get_feature_names(),
    predictors
])

# %%
list(feature_names)
# Out:
# ['00',
#  '00 16',
#  '00 17',
#  '00 18',
#  '00 19',
#  '00 20',
#  '00 21',
#  '00 22',
#  '00 23',
#  '00 адресу',
#  '00 вс',
#  '00 выходные',
#  '00 выходных',
#  '00 обеда',
#  '00 перерыва',
#  '00 руб',
#  '00 сб',
#  '00 час',
#  '000',
#  '000 000',
#  '000 км',
#  '000 руб',
#  '000 рублей',
#  '000р',
#  '000руб',
#  '001',
#  '01',
#  '02',
#  '02 2017',
#  '03',
#  '03 17',
#  '03 2017',
#  '04',
#  '04 2017',
#  '05',
#  '06',
#  '07',
#  '08',
#  '08 00',
#  '09',
#  '09 00',
#  '10',
#  '10 00',
#  '10 000',
#  '10 10',
#  '10 100',
#  '10 11',
#  '10 12',
#  '10 15',
#  '10 18',
#  '10 19',
#  '10 20',
#  '10 дней',
#  '10 дюймов',
#  '10 кв',
#  '10 кг',
#  '10 км',
#  '10 лет',
#  '10 месяцев',
#  '10 метров',
#  '10 мин',
#  '10 минут',
#  '10 минутах',
#  '10 мм',
#  '10 руб',
#  '10 рублей',
#  '10 см',
#  '10 соток',
#  '10 ти',
#  '10 тыс',
#  '10 шт',
#  '10 штук',
#  '10 этажного',
#  '100',
#  '100 000',
#  '100 150',
#  '100 гарантия',
#  '100 гр',
#  '100 кв',
#  '100 кг',
#  '100 км',
#  '100 мбит',
#  '100 метрах',
#  '100 метров',
#  '100 мл',
#  '100 мм',
#  '100 мод',
#  '100 оригинал',
#  '100 полиэстер',
#  '100 руб',
#  '100 рублей',
#  '100 см',
#  '100 хлопка',
#  '100 хлопок',
#  '100 шерсть',
#  '100 шт',
#  '1000',
#  '1000 мод',
#  '1000 моделей',
#  '1000 руб',
#  '1000 рублей',
#  '10000',
#  '10000 руб',
#  '100000',
#  '100000 тысяч',
#  '1000р',
#  '1000руб',
#  '100м',
#  '100мм',
#  '100р',
#  '100руб',
#  '100см',
#  '101',
#  '102',
#  '1024',
#  '1024x600',
#  '103',
#  '104',
#  '104 110',
#  '104 см',
#  '104см',
#  '105',
#  '1050',
#  '106',
#  '1066',
#  '107',
#  '108',
#  '1080',
#  '1080p',
#  '109',
#  '10м',
#  '10мм',
#  '10р',
#  '10см',
#  '10шт',
#  '11',
#  '11 00',
#  '11 12',
#  '11 19',
#  '11 кв',
#  '11 кг',
#  '11 лет',
#  '11 см',
#  '110',
#  '110 116',
#  '110 см',
#  '1100',
#  '11000',
#  '110см',
#  '111',
#  '112',
#  '113',
#  '114',
#  '115',
#  '1150',
#  '116',
#  '116 122',
#  '116 см',
#  '117',
#  '118',
#  '119',
#  '11b',
#  '11n',
#  '12',
#  '12 00',
#  '12 000',
#  '12 13',
#  '12 14',
#  '12 18',
#  '12 кв',
#  '12 кг',
#  '12 лет',
#  '12 мес',
#  '12 месяцев',
#  '12 мм',
#  '12 см',
#  '12 соток',
#  '12 шт',
#  '120',
#  '120 кг',
#  '120 мм',
#  '120 руб',
#  '120 см',
#  '1200',
#  '1200 мгц',
#  '1200 руб',
#  '1200 рублей',
#  '12000',
#  '1200р',
#  '121',
#  '122',
#  '122 128',
#  '122 см',
#  '123',
#  '124',
#  '125',
#  '125 см',
#  '1250',
#  '126',
#  '127',
#  '128',
#  '128 134',
#  '128 гб',
#  '128 см',
#  '1280',
#  '1280x1024',
#  '1280x720',
#  '1280x720 камера',
#  '1280x800',
#  '128gb',
#  '129',
#  '12v',
#  '12в',
#  '12м',
#  '12см',
#  '13',
#  '13 14',
#  '13 кв',
#  '13 кг',
#  '13 лет',
#  '13 мп',
#  '13 см',
#  '130',
#  '130 см',
#  '1300',
#  '1300 мгц',
#  '1300 руб',
#  '13000',
#  '1300р',
#  '132',
#  '133',
#  '1333',
#  '134',
#  '134 140',
#  '135',
#  '1350',
#  '136',
#  '1366x768',
#  '137',
#  '138',
#  '13см',
#  '14',
#  '14 00',
#  '14 дней',
#  '14 кв',
#  '14 кг',
#  '14 лет',
#  '14 см',
#  '140',
#  '140 146',
#  '140 см',
#  '1400',
#  '14000',
#  '140см',
#  '142',
#  '144',
#  '145',
#  '146',
#  '146 152',
#  '148',
#  '14см',
#  '15',
#  '15 00',
#  '15 000',
#  '15 20',
#  '15 дюймов',
#  '15 кв',
#  '15 квт',
#  '15 кг',
#  '15 км',
#  '15 лет',
#  '15 мин',
#  '15 минут',
#  '15 см',
#  '15 соток',
#  '150',
#  '150 мм',
#  '150 руб',
#  '150 рублей',
#  '150 см',
#  '1500',
#  '1500 руб',
#  '1500 рублей',
#  '15000',
#  '1500р',
#  '1500руб',
#  '150р',
#  '150руб',
#  '152',
#  '152 см',
#  '155',
#  '156',
#  '158',
#  '15см',
#  '16',
#  '16 00',
#  '16 gb',
#  '16 гб',
#  '16 кв',
#  '16 млн',
#  '16 мм',
#  '16 см',
#  '160',
#  '160 см',
#  '1600',
#  '1600 мгц',
#  '16000',
#  '162',
#  '163',
#  '164',
#  '165',
#  '165 см',
#  '1650',
#  '167',
#  '168',
#  '16gb',
#  '16гб',
#  '16см',
#  '17',
#  '17 00',
#  '17 кв',
#  '17 см',
#  '170',
#  '170 см',
#  '1700',
#  '174',
#  '175',
#  '176',
#  '178',
#  '17см',
#  '18',
#  '18 00',
#  '18 24',
#  '18 кв',
#  '18 кг',
#  '18 мес',
#  '18 месяцев',
#  '18 см',
#  '18 суббота',
#  '180',
#  '180 см',
#  '1800',
#  '1800 1900',
#  '18000',
#  '1800р',
#  '182',
#  '185',
#  '188',
#  '18см',
#  '19',
#  '19 00',
#  '19 30',
#  '19 кв',
#  '19 размер',
#  '19 см',
#  '19 цокольный',
#  '19 часов',
#  '190',
#  '190 см',
#  '1900',
#  '1900 3g',
#  '192',
#  '1920',
#  '1920 1080',
#  '1920x1080',
#  '195',
#  '1950',
#  '1980',
#  '1988',
#  '1989',
#  '1990',
#  '1990 руб',
#  '1991',
#  '1992',
#  '1993',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '1gb',
#  '1tb',
#  '1x',
#  '1а',
#  '1гб',
#  '1год',
#  '1к',
#  '1кг',
#  '1м',
#  '1раз',
#  '1с',
#  '1шт',
#  '1этаж',
#  '20',
#  '20 00',
#  '20 000',
#  '20 20',
#  '20 21',
#  '20 25',
#  '20 30',
#  '20 40',
#  '20 кв',
#  '20 кг',
#  '20 км',
#  '20 лет',
#  '20 метров',
#  '20 минут',
#  '20 мм',
#  '20 размер',
#  '20 руб',
#  '20 см',
#  '20 соток',
#  '20 цена',
#  '20 часов',
#  '20 шт',
#  '200',
#  '200 000',
#  '200 мм',
#  '200 руб',
#  '200 рублей',
#  '200 см',
#  '2000',
#  '2000 руб',
#  '2000 рублей',
#  '20000',
#  '20000 гц',
#  '2000р',
#  '2000руб',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2006 года',
#  '2006г',
#  '2007',
#  '2007 года',
#  '2007г',
#  '2008',
#  '2008 года',
#  '2008г',
#  '2009',
#  '2009 года',
#  '200р',
#  '200руб',
#  '201',
#  '2010',
#  '2010 года',
#  '2010г',
#  '2011',
#  '2011 года',
#  '2011г',
#  '2012',
#  '2012 года',
#  '2012г',
#  '2013',
#  '2013 года',
#  '2013г',
#  '2014',
#  '2014 года',
#  '2014 году',
#  '2014г',
#  '2015',
#  '2015 года',
#  '2015 году',
#  '2015г',
#  '2016',
#  '2016 года',
#  '2016 году',
#  '2016г',
#  '2017',
#  '2017 года',
#  '2017г',
#  '2018',
#  '2018 года',
#  '2018г',
#  '2019',
#  '2048',
#  '205',
#  '209',
#  '20м',
#  '20р',
#  '20см',
#  '21',
#  '21 00',
#  '21 22',
#  '21 размер',
#  '21 скорость',
#  '21 см',
#  '210',
#  '2100',
#  '2107',
#  '2110',
#  '2114',
#  '214',
#  '214 фз',
#  '215',
#  '22',
#  '22 00',
#  '22 23',
#  '22 размер',
#  '22 см',
#  '220',
#  '2200',
#  '220v',
#  '220в',
#  '225',
#  '23',
#  '23 00',
#  '23 24',
#  '23 размер',
#  '23 см',
#  '230',
#  '2300',
#  '235',
#  '24',
#  '24 25',
#  '24 кв',
#  '24 мес',
#  '24 размер',
#  '24 см',
#  '24 часа',
#  '240',
#  '2400',
#  '245',
#  '25',
#  '25 000',
#  '25 26',
#  '25 кв',
#  '25 кг',
#  '25 лет',
#  '25 мм',
#  '25 размер',
#  '25 см',
#  '250',
#  '250 гб',
#  '250 руб',
#  '250 рублей',
#  '2500',
#  '2500 руб',
#  '2500 рублей',
#  '25000',
#  '2500р',
#  '250gb',
#  '250р',
#  '250руб',
#  '256',
#  '25р',
#  '25см',
#  '26',
#  '26 27',
#  '26 размер',
#  '26 см',
#  '260',
#  '2600',
#  '264',
#  '27',
#  '27 28',
#  '27 размер',
#  '27 см',
#  '270',
#  '2700',
#  '28',
#  '28 29',
#  '28 размер',
#  '28 см',
#  '280',
#  '2800',
#  '29',
#  '29 см',
#  '290',
#  '2900',
#  '2g',
#  '2gb',
#  '2x',
#  '2а',
#  '2в1',
#  '2гб',
#  '2года',
#  '2к',
#  '2м',
#  '2мм',
#  '2х',
#  '2х комнатная',
#  '2х комнатную',
#  '2шт',
#  '30',
#  '30 000',
#  '30 40',
#  '30 60',
#  '30 дней',
#  '30 кв',
#  '30 кг',
#  '30 мин',
#  '30 минут',
#  '30 мм',
#  '30 руб',
#  '30 см',
#  '30 шт',
#  '30 штук',
#  '300',
#  '300 мм',
#  '300 руб',
#  '300 рублей',
#  '3000',
#  '3000 руб',
#  '3000 рублей',
#  '30000',
#  '3000р',
#  '300р',
#  '300руб',
#  '305',
#  '30р',
#  '30см',
#  '31',
#  '31 см',
#  '310',
#  '3100',
#  '32',
#  '32 gb',
#  '32 гб',
#  '32 кв',
#  '32 см',
#  '320',
#  '320 гб',
#  '3200',
#  '320gb',
#  '320x240',
#  '32gb',
#  '32гб',
#  '33',
#  '33 см',
#  '330',
#  '3300',
#  '34',
#  '34 см',
#  '340',
#  '35',
#  '35 36',
#  '35 кв',
#  '35 мм',
#  '35 размер',
#  '35 см',
#  '350',
#  '350 руб',
#  '350 рублей',
#  '3500',
#  '3500 руб',
#  '3500р',
#  '350р',
#  '350руб',
#  '35см',
#  '36',
#  '36 37',
#  '36 кв',
#  '36 кг',
#  '36 месяцев',
#  '36 размер',
#  '36 см',
#  '360',
#  '360 градусов',
#  '3600',
#  '37',
#  '37 38',
#  '37 размер',
#  '37 размера',
#  '37 см',
#  '370',
#  '38',
#  '38 39',
#  '38 40',
#  '38 размер',
#  '38 размера',
#  '38 см',
#  '380',
#  '3800',
#  '380в',
#  '39',
#  '39 40',
#  '39 размер',
#  '39 см',
#  '390',
#  '3d',
#  '3g',
#  '3g 4g',
#  '3g wi',
#  '3gb',
#  '3в1',
#  '3года',
#  '3д',
#  '3м',
#  '3мм',
#  '3т',
#  '3х',
#  '3х комнатную',
#  '3х лет',
#  '3шт',
#  '40',
#  '40 40',
#  '40 41',
#  '40 42',
#  '40 44',
#  '40 45',
#  '40 50',
#  '40 60',
#  '40 кв',
#  '40 кг',
#  '40 лет',
#  '40 мм',
#  '40 размер',
#  '40 руб',
#  '40 см',
#  '400',
#  '400 мм',
#  '400 руб',
#  '400 рублей',
#  '4000',
#  '4000 руб',
#  '4000р',
#  '400р',
#  '400руб',
#  '405',
#  '406',
#  '4096',
#  '40р',
#  '40см',
#  '41',
#  '41 42',
#  '41 см',
#  '410',
#  '4100',
#  '42',
#  '42 43',
#  '42 44',
#  '42 46',
#  '42 кв',
#  '42 размер',
#  '42 размера',
#  '42 см',
#  '420',
#  '4200',
#  '43',
#  '43 44',
#  '43 см',
#  '430',
#  '44',
#  '44 46',
#  '44 48',
#  '44 размер',
#  '44 размера',
#  '44 см',
#  '440',
#  '44р',
#  '45',
#  '45 кв',
#  '45 см',
#  '450',
#  '450 руб',
#  '4500',
#  '4500 руб',
#  '450р',
#  '45см',
#  '46',
#  '46 48',
#  '46 размер',
#  '46 размера',
#  '46 рост',
#  '46 см',
#  '46 цена',
#  '460',
#  '47',
#  '47 см',
#  '470',
#  '48',
#  '48 50',
#  '48 размер',
#  '48 см',
#  '480',
#  '49',
#  '49 см',
#  '490',
#  '4g',
#  '4g lte',
#  '4gb',
#  '4gb жесткий',
#  '4s',
#  '4x',
#  '4гб',
#  '4м',
#  '4мм',
#  '4х',
#  '4шт',
#  '50',
#  '50 000',
#  '50 100',
#  '50 50',
#  '50 52',
#  '50 60',
#  '50 гц',
#  '50 кв',
#  '50 кг',
#  '50 лет',
#  '50 магазинов',
#  '50 метров',
#  '50 мл',
#  '50 мм',
#  '50 размер',
#  '50 руб',
#  '50 рублей',
#  '50 см',
#  '50 шт',
#  '500',
#  '500 000',
#  '500 gb',
#  '500 гб',
#  '500 мм',
#  '500 руб',
#  '500 рублей',
#  '5000',
#  '5000 руб',
#  '5000 рублей',
#  '50000',
#  '50000 товаров',
#  '5000р',
#  '500gb',
#  '500gb видеокарта',
#  '500гб',
#  '500р',
#  '500руб',
#  '50м',
#  '50мм',
#  '50р',
#  '50руб',
#  '50см',
#  '51',
#  '51 см',
#  '510',
#  '512',
#  '512 мб',
#  '512mb',
#  '52',
#  '52 54',
#  '52 см',
#  '520',
#  '53',
#  '53 см',
#  '530',
#  '54',
#  '54 56',
#  '54 см',
#  '540',
#  '5400',
#  '55',
#  '55 корпус',
#  '55 см',
#  '550',
#  '550 руб',
#  '5500',
#  '55см',
#  '56',
#  '56 58',
#  '56 см',
#  '560',
#  '57',
#  '57 см',
#  '570',
#  '58',
#  '58 см',
#  '580',
#  '585',
#  '585 вес',
#  '585 пробы',
#  '59',
#  '59 см',
#  '5c',
#  '5s',
#  '5s 16gb',
#  '5v',
#  '5кг',
#  '5л',
#  '5лет',
#  '5м',
#  '5мм',
#  '5мп',
#  '5см',
#  '5т',
#  '5шт',
#  '60',
#  '60 кв',
#  '60 мм',
#  '60 руб',
#  '60 см',
#  '600',
#  '600 мм',
#  '600 мод',
#  '600 руб',
#  '600 рублей',
#  '6000',
#  '6000 руб',
#  '600р',
#  '600руб',
#  '60см',
#  '61',
#  '61 см',
#  '62',
#  '62 68',
#  '62 см',
#  '620',
#  '63',
#  '63 см',
#  '630',
#  '64',
#  '64 гб',
#  '64 см',
#  '640',
#  '64gb',
#  '65',
#  '65 см',
#  '650',
#  '650 руб',
#  '6500',
#  '66',
#  '66 см',
#  '67',
#  '67 см',
#  '68',
#  '68 74',
#  '68 см',
#  '68см',
#  '69',
#  '6gb',
#  '6s',
#  '6м',
#  '6мес',
#  '6шт',
#  '70',
#  '70 кв',
#  '70 мм',
#  '70 руб',
#  '70 см',
#  '700',
#  '700 руб',
#  '700 рублей',
#  '7000',
#  '700р',
#  '70р',
#  '70см',
#  '71',
#  '72',
#  '72 см',
#  '720',
#  '7200',
#  '720p',
#  '73',
#  '74',
#  '74 80',
#  '74 см',
#  '74см',
#  '75',
#  '75 см',
#  '750',
#  '750 руб',
#  '7500',
#  '76',
#  '76 см',
#  '768',
#  '77',
#  '775',
#  '78',
#  '79',
#  '7м',
#  '80',
#  '80 86',
#  '80 кв',
#  '80 мм',
#  '80 руб',
#  '80 см',
#  '800',
#  '800 мм',
#  '800 руб',
#  '800 рублей',
#  '8000',
#  '800x480',
#  '800x480 камера',
#  '800р',
#  '800руб',
#  '802',
#  '802 11',
#  '802 11b',
#  '802 11n',
#  '80р',
#  '80см',
#  '81',
#  '81 см',
#  '82',
#  '82 см',
#  '83',
#  '84',
#  '85',
#  '85 см',
#  ...]

# %%
with open('feature_names', 'wb') as handle:
    pickle.dump(feature_names, handle, protocol=pickle.HIGHEST_PROTOCOL)
    
with open('cat_feature_names', 'wb') as handle:
    pickle.dump(categorical, handle, protocol=pickle.HIGHEST_PROTOCOL)
