# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import gc; gc.enable()
import pickle
from tqdm import tqdm
import warnings ; warnings.filterwarnings('ignore')
import os
from GridSearcher import data_loader, model_loader, fit_params, get_oof_predictions

# %%
folder = 'final oofs 719/'
os.listdir(folder)
# Out:
# ['baseline_xgb_719_oof_test_pred.csv',
#  'baseline_xgb_719_oof_val_pred.csv',
#  'cgb719_with_categorical_oof_test_pred.csv',
#  'cgb719_with_categorical_oof_val_pred.csv',
#  'lgb719_goss_append_keypoint_oof_test_pred.csv',
#  'lgb719_goss_append_keypoint_oof_val_pred.csv',
#  'rf719_oof_test_pred.csv',
#  'rf719_oof_val_pred.csv',
#  'ridge_new_719_oof_test_pred.csv',
#  'ridge_new_719_oof_val_pred.csv',
#  'selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_oof_test_pred.csv',
#  'selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_oof_val_pred.csv',
#  'xentropy_add_lotsof_image_features_lgb719_oof_test_pred.csv',
#  'xentropy_add_lotsof_image_features_lgb719_oof_val_pred.csv']

# %%
prefixs = [
    'xentropy_add_lotsof_image_features_lgb719',
    'baseline_xgb_719',
    'cgb719_with_categorical',
    'lgb719_goss_append_keypoint',
    'rf719',
    'ridge_new_719',
    'selftrained_bigru_conv1d_merged_with_image_adv_719_rnn'
]

# %%
train = pd.DataFrame()
test = pd.DataFrame()

# %%
from scipy.stats import hmean
from scipy.stats.mstats import gmean

def get_clipped_values(a):
    return np.clip(a, 1e-15, 1.)

for prefix in prefixs:
    train_f = folder + prefix + '_oof_val_pred.csv'
    test_f = folder + prefix + '_oof_test_pred.csv'

    train_df = pd.read_csv(train_f)
    test_df = pd.read_csv(test_f)

    original_col = train_df.columns.tolist()[0]
    col = prefix
    print('Add ', col)
    
    train.loc[:,col] = train_df[original_col]
    test.loc[:,col] = test_df[original_col]

    del train_df, test_df; gc.collect()

for df in [train, test]:    
    # within sample group
    df.loc[:, 'all_mean'] = df[prefixs].mean(axis=1)
    df.loc[:, 'all_med'] = df[prefixs].median(axis=1)
    df.loc[:, 'all_max'] = df[prefixs].max(axis=1)
    df.loc[:, 'all_min'] = df[prefixs].min(axis=1)
    df.loc[:, 'all_std'] = df[prefixs].std(axis=1)

    col_len = len(prefixs)
    for i in range(col_len-1):
        for j in range(i+1, col_len):
            cols = [prefixs[i], prefixs[j]]
            feat_name = cols[0]+'_'+cols[1]+'_inter'
            print('Add ', feat_name, ' statistcs')        
            df.loc[:, feat_name+'_mean'] = df[cols].mean(axis=1)
            df.loc[:, feat_name+'_gmean'] = gmean(get_clipped_values(df[cols].values), axis=1)
            df.loc[:, feat_name+'_hmean'] = hmean(get_clipped_values(df[cols].values), axis=1)
    
    col_len = len(prefixs)
    for i in range(col_len-2):
        for j in range(i+1, col_len-1):
            for k in range(j+1, col_len):
                cols = [prefixs[i], prefixs[j], prefixs[k]]
                feat_name = cols[0]+'_'+cols[1]+'_'+cols[2]+'_inter'  
                print('Add ', feat_name, ' statistcs')                    
                df.loc[:, feat_name+'_mean'] = df[cols].mean(axis=1)
                df.loc[:, feat_name+'_gmean'] = gmean(get_clipped_values(df[cols].values), axis=1)
                df.loc[:, feat_name+'_hmean'] = hmean(get_clipped_values(df[cols].values), axis=1)
                df.loc[:, feat_name+'_med'] = df[cols].median(axis=1)
                df.loc[:, feat_name+'_std'] = df[cols].std(axis=1)                        
    #df = df.astype(np.float32)
# Out:
# Add  xentropy_add_lotsof_image_features_lgb719
# Add  baseline_xgb_719
# Add  cgb719_with_categorical
# Add  lgb719_goss_append_keypoint
# Add  rf719
# Add  ridge_new_719
# Add  selftrained_bigru_conv1d_merged_with_image_adv_719_rnn
# Add  xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_inter  statistcs
# Add  xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_inter  statistcs
# Add  xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_inter  statistcs
# Add  xentropy_add_lotsof_image_features_lgb719_rf719_inter  statistcs
# Add  xentropy_add_lotsof_image_features_lgb719_ridge_new_719_inter  statistcs
# Add  xentropy_add_lotsof_image_features_lgb719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter  statistcs
# Add  baseline_xgb_719_cgb719_with_categorical_inter  statistcs
# Add  baseline_xgb_719_lgb719_goss_append_keypoint_inter  statistcs
# Add  baseline_xgb_719_rf719_inter  statistcs
# Add  baseline_xgb_719_ridge_new_719_inter  statistcs
# Add  baseline_xgb_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter  statistcs
# Add  cgb719_with_categorical_lgb719_goss_append_keypoint_inter  statistcs
# Add  cgb719_with_categorical_rf719_inter  statistcs
# Add  cgb719_with_categorical_ridge_new_719_inter  statistcs
# Add  cgb719_with_categorical_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter  statistcs
# Add  lgb719_goss_append_keypoint_rf719_inter  statistcs
# Add  lgb719_goss_append_keypoint_ridge_new_719_inter  statistcs
# Add  lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter  statistcs
# Add  rf719_ridge_new_719_inter  statistcs
# Add  rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter  statistcs
# Add  ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter  statistcs
# Add  xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_cgb719_with_categorical_inter  statistcs
# Add  xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_lgb719_goss_append_keypoint_inter  statistcs
# Add  xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_rf719_inter  statistcs
# Add  xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_ridge_new_719_inter  statistcs
# Add  xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter  statistcs
# Add  xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_lgb719_goss_append_keypoint_inter  statistcs
# Add  xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_rf719_inter  statistcs
# Add  xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_ridge_new_719_inter  statistcs
# Add  xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter  statistcs
# Add  xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_rf719_inter  statistcs
# Add  xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_ridge_new_719_inter  statistcs
# Add  xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter  statistcs
# Add  xentropy_add_lotsof_image_features_lgb719_rf719_ridge_new_719_inter  statistcs
# Add  xentropy_add_lotsof_image_features_lgb719_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter  statistcs
# Add  xentropy_add_lotsof_image_features_lgb719_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter  statistcs
# Add  baseline_xgb_719_cgb719_with_categorical_lgb719_goss_append_keypoint_inter  statistcs
# Add  baseline_xgb_719_cgb719_with_categorical_rf719_inter  statistcs
# Add  baseline_xgb_719_cgb719_with_categorical_ridge_new_719_inter  statistcs
# Add  baseline_xgb_719_cgb719_with_categorical_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter  statistcs
# Add  baseline_xgb_719_lgb719_goss_append_keypoint_rf719_inter  statistcs
# Add  baseline_xgb_719_lgb719_goss_append_keypoint_ridge_new_719_inter  statistcs
# Add  baseline_xgb_719_lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter  statistcs
# Add  baseline_xgb_719_rf719_ridge_new_719_inter  statistcs
# Add  baseline_xgb_719_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter  statistcs
# Add  baseline_xgb_719_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter  statistcs
# Add  cgb719_with_categorical_lgb719_goss_append_keypoint_rf719_inter  statistcs
# Add  cgb719_with_categorical_lgb719_goss_append_keypoint_ridge_new_719_inter  statistcs
# Add  cgb719_with_categorical_lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter  statistcs
# Add  cgb719_with_categorical_rf719_ridge_new_719_inter  statistcs
# Add  cgb719_with_categorical_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter  statistcs
# Add  cgb719_with_categorical_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter  statistcs
# Add  lgb719_goss_append_keypoint_rf719_ridge_new_719_inter  statistcs
# Add  lgb719_goss_append_keypoint_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter  statistcs
# Add  lgb719_goss_append_keypoint_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter  statistcs
# Add  rf719_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter  statistcs
# Add  xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_inter  statistcs
# Add  xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_inter  statistcs
# Add  xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_inter  statistcs
# Add  xentropy_add_lotsof_image_features_lgb719_rf719_inter  statistcs
# Add  xentropy_add_lotsof_image_features_lgb719_ridge_new_719_inter  statistcs
# Add  xentropy_add_lotsof_image_features_lgb719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter  statistcs
# Add  baseline_xgb_719_cgb719_with_categorical_inter  statistcs
# Add  baseline_xgb_719_lgb719_goss_append_keypoint_inter  statistcs
# Add  baseline_xgb_719_rf719_inter  statistcs
# Add  baseline_xgb_719_ridge_new_719_inter  statistcs
# Add  baseline_xgb_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter  statistcs
# Add  cgb719_with_categorical_lgb719_goss_append_keypoint_inter  statistcs
# Add  cgb719_with_categorical_rf719_inter  statistcs
# Add  cgb719_with_categorical_ridge_new_719_inter  statistcs
# Add  cgb719_with_categorical_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter  statistcs
# Add  lgb719_goss_append_keypoint_rf719_inter  statistcs
# Add  lgb719_goss_append_keypoint_ridge_new_719_inter  statistcs
# Add  lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter  statistcs
# Add  rf719_ridge_new_719_inter  statistcs
# Add  rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter  statistcs
# Add  ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter  statistcs
# Add  xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_cgb719_with_categorical_inter  statistcs
# Add  xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_lgb719_goss_append_keypoint_inter  statistcs
# Add  xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_rf719_inter  statistcs
# Add  xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_ridge_new_719_inter  statistcs
# Add  xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter  statistcs
# Add  xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_lgb719_goss_append_keypoint_inter  statistcs
# Add  xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_rf719_inter  statistcs
# Add  xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_ridge_new_719_inter  statistcs
# Add  xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter  statistcs
# Add  xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_rf719_inter  statistcs
# Add  xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_ridge_new_719_inter  statistcs
# Add  xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter  statistcs
# Add  xentropy_add_lotsof_image_features_lgb719_rf719_ridge_new_719_inter  statistcs
# Add  xentropy_add_lotsof_image_features_lgb719_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter  statistcs
# Add  xentropy_add_lotsof_image_features_lgb719_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter  statistcs
# Add  baseline_xgb_719_cgb719_with_categorical_lgb719_goss_append_keypoint_inter  statistcs
# Add  baseline_xgb_719_cgb719_with_categorical_rf719_inter  statistcs
# Add  baseline_xgb_719_cgb719_with_categorical_ridge_new_719_inter  statistcs
# Add  baseline_xgb_719_cgb719_with_categorical_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter  statistcs
# Add  baseline_xgb_719_lgb719_goss_append_keypoint_rf719_inter  statistcs
# Add  baseline_xgb_719_lgb719_goss_append_keypoint_ridge_new_719_inter  statistcs
# Add  baseline_xgb_719_lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter  statistcs
# Add  baseline_xgb_719_rf719_ridge_new_719_inter  statistcs
# Add  baseline_xgb_719_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter  statistcs
# Add  baseline_xgb_719_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter  statistcs
# Add  cgb719_with_categorical_lgb719_goss_append_keypoint_rf719_inter  statistcs
# Add  cgb719_with_categorical_lgb719_goss_append_keypoint_ridge_new_719_inter  statistcs
# Add  cgb719_with_categorical_lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter  statistcs
# Add  cgb719_with_categorical_rf719_ridge_new_719_inter  statistcs
# Add  cgb719_with_categorical_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter  statistcs
# Add  cgb719_with_categorical_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter  statistcs
# Add  lgb719_goss_append_keypoint_rf719_ridge_new_719_inter  statistcs
# Add  lgb719_goss_append_keypoint_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter  statistcs
# Add  lgb719_goss_append_keypoint_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter  statistcs
# Add  rf719_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter  statistcs

# %%
train.head(3)
# Out:
#    xentropy_add_lotsof_image_features_lgb719  baseline_xgb_719  \
# 0                                   0.060275          0.079386
# 1                                   0.049319          0.049824
# 2                                   0.039271          0.032743
#
#    cgb719_with_categorical  lgb719_goss_append_keypoint     rf719  \
# 0                 0.077960                     0.068296  0.055568
# 1                 0.035870                     0.050909  0.028820
# 2                 0.030674                     0.032980  0.051158
#
#    ridge_new_719  selftrained_bigru_conv1d_merged_with_image_adv_719_rnn  \
# 0       0.060719                                           0.055605
# 1       0.049040                                           0.042389
# 2       0.055162                                           0.044281
#
#    all_mean   all_med   all_max  \
# 0  0.065401  0.060719  0.079386
# 1  0.043739  0.049040  0.050909
# 2  0.040896  0.039271  0.055162
#
#                                            ...                                           \
# 0                                          ...
# 1                                          ...
# 2                                          ...
#
#    lgb719_goss_append_keypoint_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean  \
# 0                                           0.061540
# 1                                           0.047446
# 2                                           0.044141
#
#    lgb719_goss_append_keypoint_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean  \
# 0                                           0.061321
# 1                                           0.047300
# 2                                           0.043189
#
#    lgb719_goss_append_keypoint_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean  \
# 0                                           0.061105
# 1                                           0.047151
# 2                                           0.042234
#
#    lgb719_goss_append_keypoint_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_med  \
# 0                                           0.060719
# 1                                           0.049040
# 2                                           0.044281
#
#    lgb719_goss_append_keypoint_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_std  \
# 0                                           0.006385
# 1                                           0.004478
# 2                                           0.011091
#
#    rf719_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean  \
# 0                                           0.057297
# 1                                           0.040083
# 2                                           0.050200
#
#    rf719_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean  \
# 0                                           0.057247
# 1                                           0.039129
# 2                                           0.049995
#
#    rf719_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean  \
# 0                                           0.057198
# 1                                           0.038129
# 2                                           0.049785
#
#    rf719_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_med  \
# 0                                           0.055605
# 1                                           0.042389
# 2                                           0.051158
#
#    rf719_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_std
# 0                                           0.002964
# 1                                           0.010305
# 2                                           0.005503
#
# [3 rows x 250 columns]

# %%
pd.options.display.max_rows=100
pd.options.display.max_columns=100
train[prefixs].corr()
# Out:
#                                                     xentropy_add_lotsof_image_features_lgb719  \
# xentropy_add_lotsof_image_features_lgb719                                            1.000000
# baseline_xgb_719                                                                     0.978145
# cgb719_with_categorical                                                              0.971084
# lgb719_goss_append_keypoint                                                          0.989260
# rf719                                                                                0.922805
# ridge_new_719                                                                        0.873556
# selftrained_bigru_conv1d_merged_with_image_adv_...                                   0.916805
#
#                                                     baseline_xgb_719  \
# xentropy_add_lotsof_image_features_lgb719                   0.978145
# baseline_xgb_719                                            1.000000
# cgb719_with_categorical                                     0.958515
# lgb719_goss_append_keypoint                                 0.972856
# rf719                                                       0.915871
# ridge_new_719                                               0.861750
# selftrained_bigru_conv1d_merged_with_image_adv_...          0.904890
#
#                                                     cgb719_with_categorical  \
# xentropy_add_lotsof_image_features_lgb719                          0.971084
# baseline_xgb_719                                                   0.958515
# cgb719_with_categorical                                            1.000000
# lgb719_goss_append_keypoint                                        0.975940
# rf719                                                              0.934553
# ridge_new_719                                                      0.885376
# selftrained_bigru_conv1d_merged_with_image_adv_...                 0.908931
#
#                                                     lgb719_goss_append_keypoint  \
# xentropy_add_lotsof_image_features_lgb719                              0.989260
# baseline_xgb_719                                                       0.972856
# cgb719_with_categorical                                                0.975940
# lgb719_goss_append_keypoint                                            1.000000
# rf719                                                                  0.922859
# ridge_new_719                                                          0.873763
# selftrained_bigru_conv1d_merged_with_image_adv_...                     0.914048
#
#                                                        rf719  ridge_new_719  \
# xentropy_add_lotsof_image_features_lgb719           0.922805       0.873556
# baseline_xgb_719                                    0.915871       0.861750
# cgb719_with_categorical                             0.934553       0.885376
# lgb719_goss_append_keypoint                         0.922859       0.873763
# rf719                                               1.000000       0.945654
# ridge_new_719                                       0.945654       1.000000
# selftrained_bigru_conv1d_merged_with_image_adv_...  0.880436       0.840825
#
#                                                     selftrained_bigru_conv1d_merged_with_image_adv_719_rnn
# xentropy_add_lotsof_image_features_lgb719                                                    0.916805
# baseline_xgb_719                                                                             0.904890
# cgb719_with_categorical                                                                      0.908931
# lgb719_goss_append_keypoint                                                                  0.914048
# rf719                                                                                        0.880436
# ridge_new_719                                                                                0.840825
# selftrained_bigru_conv1d_merged_with_image_adv_...                                           1.000000

# %%
train.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1503424 entries, 0 to 1503423
# Data columns (total 250 columns):
# xentropy_add_lotsof_image_features_lgb719                                                                                                   float64
# baseline_xgb_719                                                                                                                            float64
# cgb719_with_categorical                                                                                                                     float64
# lgb719_goss_append_keypoint                                                                                                                 float64
# rf719                                                                                                                                       float64
# ridge_new_719                                                                                                                               float64
# selftrained_bigru_conv1d_merged_with_image_adv_719_rnn                                                                                      float64
# all_mean                                                                                                                                    float64
# all_med                                                                                                                                     float64
# all_max                                                                                                                                     float64
# all_min                                                                                                                                     float64
# all_std                                                                                                                                     float64
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_inter_mean                                                                       float64
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_inter_gmean                                                                      float64
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_inter_hmean                                                                      float64
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_inter_mean                                                                float64
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_inter_gmean                                                               float64
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_inter_hmean                                                               float64
# xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_inter_mean                                                            float64
# xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_inter_gmean                                                           float64
# xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_inter_hmean                                                           float64
# xentropy_add_lotsof_image_features_lgb719_rf719_inter_mean                                                                                  float64
# xentropy_add_lotsof_image_features_lgb719_rf719_inter_gmean                                                                                 float64
# xentropy_add_lotsof_image_features_lgb719_rf719_inter_hmean                                                                                 float64
# xentropy_add_lotsof_image_features_lgb719_ridge_new_719_inter_mean                                                                          float64
# xentropy_add_lotsof_image_features_lgb719_ridge_new_719_inter_gmean                                                                         float64
# xentropy_add_lotsof_image_features_lgb719_ridge_new_719_inter_hmean                                                                         float64
# xentropy_add_lotsof_image_features_lgb719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean                                 float64
# xentropy_add_lotsof_image_features_lgb719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean                                float64
# xentropy_add_lotsof_image_features_lgb719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean                                float64
# baseline_xgb_719_cgb719_with_categorical_inter_mean                                                                                         float64
# baseline_xgb_719_cgb719_with_categorical_inter_gmean                                                                                        float64
# baseline_xgb_719_cgb719_with_categorical_inter_hmean                                                                                        float64
# baseline_xgb_719_lgb719_goss_append_keypoint_inter_mean                                                                                     float64
# baseline_xgb_719_lgb719_goss_append_keypoint_inter_gmean                                                                                    float64
# baseline_xgb_719_lgb719_goss_append_keypoint_inter_hmean                                                                                    float64
# baseline_xgb_719_rf719_inter_mean                                                                                                           float64
# baseline_xgb_719_rf719_inter_gmean                                                                                                          float64
# baseline_xgb_719_rf719_inter_hmean                                                                                                          float64
# baseline_xgb_719_ridge_new_719_inter_mean                                                                                                   float64
# baseline_xgb_719_ridge_new_719_inter_gmean                                                                                                  float64
# baseline_xgb_719_ridge_new_719_inter_hmean                                                                                                  float64
# baseline_xgb_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean                                                          float64
# baseline_xgb_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean                                                         float64
# baseline_xgb_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean                                                         float64
# cgb719_with_categorical_lgb719_goss_append_keypoint_inter_mean                                                                              float64
# cgb719_with_categorical_lgb719_goss_append_keypoint_inter_gmean                                                                             float64
# cgb719_with_categorical_lgb719_goss_append_keypoint_inter_hmean                                                                             float64
# cgb719_with_categorical_rf719_inter_mean                                                                                                    float64
# cgb719_with_categorical_rf719_inter_gmean                                                                                                   float64
# cgb719_with_categorical_rf719_inter_hmean                                                                                                   float64
# cgb719_with_categorical_ridge_new_719_inter_mean                                                                                            float64
# cgb719_with_categorical_ridge_new_719_inter_gmean                                                                                           float64
# cgb719_with_categorical_ridge_new_719_inter_hmean                                                                                           float64
# cgb719_with_categorical_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean                                                   float64
# cgb719_with_categorical_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean                                                  float64
# cgb719_with_categorical_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean                                                  float64
# lgb719_goss_append_keypoint_rf719_inter_mean                                                                                                float64
# lgb719_goss_append_keypoint_rf719_inter_gmean                                                                                               float64
# lgb719_goss_append_keypoint_rf719_inter_hmean                                                                                               float64
# lgb719_goss_append_keypoint_ridge_new_719_inter_mean                                                                                        float64
# lgb719_goss_append_keypoint_ridge_new_719_inter_gmean                                                                                       float64
# lgb719_goss_append_keypoint_ridge_new_719_inter_hmean                                                                                       float64
# lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean                                               float64
# lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean                                              float64
# lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean                                              float64
# rf719_ridge_new_719_inter_mean                                                                                                              float64
# rf719_ridge_new_719_inter_gmean                                                                                                             float64
# rf719_ridge_new_719_inter_hmean                                                                                                             float64
# rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean                                                                     float64
# rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean                                                                    float64
# rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean                                                                    float64
# ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean                                                             float64
# ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean                                                            float64
# ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean                                                            float64
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_cgb719_with_categorical_inter_mean                                               float64
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_cgb719_with_categorical_inter_gmean                                              float64
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_cgb719_with_categorical_inter_hmean                                              float64
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_cgb719_with_categorical_inter_med                                                float64
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_cgb719_with_categorical_inter_std                                                float64
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_lgb719_goss_append_keypoint_inter_mean                                           float64
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_lgb719_goss_append_keypoint_inter_gmean                                          float64
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_lgb719_goss_append_keypoint_inter_hmean                                          float64
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_lgb719_goss_append_keypoint_inter_med                                            float64
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_lgb719_goss_append_keypoint_inter_std                                            float64
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_rf719_inter_mean                                                                 float64
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_rf719_inter_gmean                                                                float64
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_rf719_inter_hmean                                                                float64
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_rf719_inter_med                                                                  float64
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_rf719_inter_std                                                                  float64
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_ridge_new_719_inter_mean                                                         float64
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_ridge_new_719_inter_gmean                                                        float64
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_ridge_new_719_inter_hmean                                                        float64
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_ridge_new_719_inter_med                                                          float64
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_ridge_new_719_inter_std                                                          float64
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean                float64
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean               float64
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean               float64
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_med                 float64
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_std                 float64
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_lgb719_goss_append_keypoint_inter_mean                                    float64
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_lgb719_goss_append_keypoint_inter_gmean                                   float64
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_lgb719_goss_append_keypoint_inter_hmean                                   float64
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_lgb719_goss_append_keypoint_inter_med                                     float64
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_lgb719_goss_append_keypoint_inter_std                                     float64
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_rf719_inter_mean                                                          float64
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_rf719_inter_gmean                                                         float64
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_rf719_inter_hmean                                                         float64
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_rf719_inter_med                                                           float64
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_rf719_inter_std                                                           float64
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_ridge_new_719_inter_mean                                                  float64
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_ridge_new_719_inter_gmean                                                 float64
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_ridge_new_719_inter_hmean                                                 float64
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_ridge_new_719_inter_med                                                   float64
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_ridge_new_719_inter_std                                                   float64
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean         float64
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean        float64
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean        float64
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_med          float64
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_std          float64
# xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_rf719_inter_mean                                                      float64
# xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_rf719_inter_gmean                                                     float64
# xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_rf719_inter_hmean                                                     float64
# xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_rf719_inter_med                                                       float64
# xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_rf719_inter_std                                                       float64
# xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_ridge_new_719_inter_mean                                              float64
# xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_ridge_new_719_inter_gmean                                             float64
# xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_ridge_new_719_inter_hmean                                             float64
# xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_ridge_new_719_inter_med                                               float64
# xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_ridge_new_719_inter_std                                               float64
# xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean     float64
# xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean    float64
# xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean    float64
# xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_med      float64
# xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_std      float64
# xentropy_add_lotsof_image_features_lgb719_rf719_ridge_new_719_inter_mean                                                                    float64
# xentropy_add_lotsof_image_features_lgb719_rf719_ridge_new_719_inter_gmean                                                                   float64
# xentropy_add_lotsof_image_features_lgb719_rf719_ridge_new_719_inter_hmean                                                                   float64
# xentropy_add_lotsof_image_features_lgb719_rf719_ridge_new_719_inter_med                                                                     float64
# xentropy_add_lotsof_image_features_lgb719_rf719_ridge_new_719_inter_std                                                                     float64
# xentropy_add_lotsof_image_features_lgb719_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean                           float64
# xentropy_add_lotsof_image_features_lgb719_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean                          float64
# xentropy_add_lotsof_image_features_lgb719_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean                          float64
# xentropy_add_lotsof_image_features_lgb719_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_med                            float64
# xentropy_add_lotsof_image_features_lgb719_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_std                            float64
# xentropy_add_lotsof_image_features_lgb719_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean                   float64
# xentropy_add_lotsof_image_features_lgb719_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean                  float64
# xentropy_add_lotsof_image_features_lgb719_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean                  float64
# xentropy_add_lotsof_image_features_lgb719_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_med                    float64
# xentropy_add_lotsof_image_features_lgb719_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_std                    float64
# baseline_xgb_719_cgb719_with_categorical_lgb719_goss_append_keypoint_inter_mean                                                             float64
# baseline_xgb_719_cgb719_with_categorical_lgb719_goss_append_keypoint_inter_gmean                                                            float64
# baseline_xgb_719_cgb719_with_categorical_lgb719_goss_append_keypoint_inter_hmean                                                            float64
# baseline_xgb_719_cgb719_with_categorical_lgb719_goss_append_keypoint_inter_med                                                              float64
# baseline_xgb_719_cgb719_with_categorical_lgb719_goss_append_keypoint_inter_std                                                              float64
# baseline_xgb_719_cgb719_with_categorical_rf719_inter_mean                                                                                   float64
# baseline_xgb_719_cgb719_with_categorical_rf719_inter_gmean                                                                                  float64
# baseline_xgb_719_cgb719_with_categorical_rf719_inter_hmean                                                                                  float64
# baseline_xgb_719_cgb719_with_categorical_rf719_inter_med                                                                                    float64
# baseline_xgb_719_cgb719_with_categorical_rf719_inter_std                                                                                    float64
# baseline_xgb_719_cgb719_with_categorical_ridge_new_719_inter_mean                                                                           float64
# baseline_xgb_719_cgb719_with_categorical_ridge_new_719_inter_gmean                                                                          float64
# baseline_xgb_719_cgb719_with_categorical_ridge_new_719_inter_hmean                                                                          float64
# baseline_xgb_719_cgb719_with_categorical_ridge_new_719_inter_med                                                                            float64
# baseline_xgb_719_cgb719_with_categorical_ridge_new_719_inter_std                                                                            float64
# baseline_xgb_719_cgb719_with_categorical_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean                                  float64
# baseline_xgb_719_cgb719_with_categorical_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean                                 float64
# baseline_xgb_719_cgb719_with_categorical_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean                                 float64
# baseline_xgb_719_cgb719_with_categorical_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_med                                   float64
# baseline_xgb_719_cgb719_with_categorical_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_std                                   float64
# baseline_xgb_719_lgb719_goss_append_keypoint_rf719_inter_mean                                                                               float64
# baseline_xgb_719_lgb719_goss_append_keypoint_rf719_inter_gmean                                                                              float64
# baseline_xgb_719_lgb719_goss_append_keypoint_rf719_inter_hmean                                                                              float64
# baseline_xgb_719_lgb719_goss_append_keypoint_rf719_inter_med                                                                                float64
# baseline_xgb_719_lgb719_goss_append_keypoint_rf719_inter_std                                                                                float64
# baseline_xgb_719_lgb719_goss_append_keypoint_ridge_new_719_inter_mean                                                                       float64
# baseline_xgb_719_lgb719_goss_append_keypoint_ridge_new_719_inter_gmean                                                                      float64
# baseline_xgb_719_lgb719_goss_append_keypoint_ridge_new_719_inter_hmean                                                                      float64
# baseline_xgb_719_lgb719_goss_append_keypoint_ridge_new_719_inter_med                                                                        float64
# baseline_xgb_719_lgb719_goss_append_keypoint_ridge_new_719_inter_std                                                                        float64
# baseline_xgb_719_lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean                              float64
# baseline_xgb_719_lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean                             float64
# baseline_xgb_719_lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean                             float64
# baseline_xgb_719_lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_med                               float64
# baseline_xgb_719_lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_std                               float64
# baseline_xgb_719_rf719_ridge_new_719_inter_mean                                                                                             float64
# baseline_xgb_719_rf719_ridge_new_719_inter_gmean                                                                                            float64
# baseline_xgb_719_rf719_ridge_new_719_inter_hmean                                                                                            float64
# baseline_xgb_719_rf719_ridge_new_719_inter_med                                                                                              float64
# baseline_xgb_719_rf719_ridge_new_719_inter_std                                                                                              float64
# baseline_xgb_719_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean                                                    float64
# baseline_xgb_719_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean                                                   float64
# baseline_xgb_719_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean                                                   float64
# baseline_xgb_719_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_med                                                     float64
# baseline_xgb_719_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_std                                                     float64
# baseline_xgb_719_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean                                            float64
# baseline_xgb_719_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean                                           float64
# baseline_xgb_719_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean                                           float64
# baseline_xgb_719_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_med                                             float64
# baseline_xgb_719_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_std                                             float64
# cgb719_with_categorical_lgb719_goss_append_keypoint_rf719_inter_mean                                                                        float64
# cgb719_with_categorical_lgb719_goss_append_keypoint_rf719_inter_gmean                                                                       float64
# cgb719_with_categorical_lgb719_goss_append_keypoint_rf719_inter_hmean                                                                       float64
# cgb719_with_categorical_lgb719_goss_append_keypoint_rf719_inter_med                                                                         float64
# cgb719_with_categorical_lgb719_goss_append_keypoint_rf719_inter_std                                                                         float64
# cgb719_with_categorical_lgb719_goss_append_keypoint_ridge_new_719_inter_mean                                                                float64
# cgb719_with_categorical_lgb719_goss_append_keypoint_ridge_new_719_inter_gmean                                                               float64
# cgb719_with_categorical_lgb719_goss_append_keypoint_ridge_new_719_inter_hmean                                                               float64
# cgb719_with_categorical_lgb719_goss_append_keypoint_ridge_new_719_inter_med                                                                 float64
# cgb719_with_categorical_lgb719_goss_append_keypoint_ridge_new_719_inter_std                                                                 float64
# cgb719_with_categorical_lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean                       float64
# cgb719_with_categorical_lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean                      float64
# cgb719_with_categorical_lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean                      float64
# cgb719_with_categorical_lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_med                        float64
# cgb719_with_categorical_lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_std                        float64
# cgb719_with_categorical_rf719_ridge_new_719_inter_mean                                                                                      float64
# cgb719_with_categorical_rf719_ridge_new_719_inter_gmean                                                                                     float64
# cgb719_with_categorical_rf719_ridge_new_719_inter_hmean                                                                                     float64
# cgb719_with_categorical_rf719_ridge_new_719_inter_med                                                                                       float64
# cgb719_with_categorical_rf719_ridge_new_719_inter_std                                                                                       float64
# cgb719_with_categorical_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean                                             float64
# cgb719_with_categorical_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean                                            float64
# cgb719_with_categorical_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean                                            float64
# cgb719_with_categorical_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_med                                              float64
# cgb719_with_categorical_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_std                                              float64
# cgb719_with_categorical_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean                                     float64
# cgb719_with_categorical_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean                                    float64
# cgb719_with_categorical_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean                                    float64
# cgb719_with_categorical_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_med                                      float64
# cgb719_with_categorical_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_std                                      float64
# lgb719_goss_append_keypoint_rf719_ridge_new_719_inter_mean                                                                                  float64
# lgb719_goss_append_keypoint_rf719_ridge_new_719_inter_gmean                                                                                 float64
# lgb719_goss_append_keypoint_rf719_ridge_new_719_inter_hmean                                                                                 float64
# lgb719_goss_append_keypoint_rf719_ridge_new_719_inter_med                                                                                   float64
# lgb719_goss_append_keypoint_rf719_ridge_new_719_inter_std                                                                                   float64
# lgb719_goss_append_keypoint_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean                                         float64
# lgb719_goss_append_keypoint_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean                                        float64
# lgb719_goss_append_keypoint_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean                                        float64
# lgb719_goss_append_keypoint_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_med                                          float64
# lgb719_goss_append_keypoint_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_std                                          float64
# lgb719_goss_append_keypoint_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean                                 float64
# lgb719_goss_append_keypoint_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean                                float64
# lgb719_goss_append_keypoint_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean                                float64
# lgb719_goss_append_keypoint_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_med                                  float64
# lgb719_goss_append_keypoint_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_std                                  float64
# rf719_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean                                                       float64
# rf719_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean                                                      float64
# rf719_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean                                                      float64
# rf719_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_med                                                        float64
# rf719_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_std                                                        float64
# dtypes: float64(250)
# memory usage: 2.8 GB

# %%
train.shape, test.shape
# Out:
# ((1503424, 250), (508438, 250))

# %%
print(train.isnull().sum().max()) 
print(test.isnull().sum().max())
# Out:
# 0
# 0

# %%
for col in tqdm(train.columns):
    train[col] = train[col].astype(np.float32)
    test[col] = test[col].astype(np.float32)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 250/250 [03:25<00:00,  1.22it/s]

# %%
train.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1503424 entries, 0 to 1503423
# Data columns (total 250 columns):
# xentropy_add_lotsof_image_features_lgb719                                                                                                   float32
# baseline_xgb_719                                                                                                                            float32
# cgb719_with_categorical                                                                                                                     float32
# lgb719_goss_append_keypoint                                                                                                                 float32
# rf719                                                                                                                                       float32
# ridge_new_719                                                                                                                               float32
# selftrained_bigru_conv1d_merged_with_image_adv_719_rnn                                                                                      float32
# all_mean                                                                                                                                    float32
# all_med                                                                                                                                     float32
# all_max                                                                                                                                     float32
# all_min                                                                                                                                     float32
# all_std                                                                                                                                     float32
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_inter_mean                                                                       float32
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_inter_gmean                                                                      float32
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_inter_hmean                                                                      float32
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_inter_mean                                                                float32
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_inter_gmean                                                               float32
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_inter_hmean                                                               float32
# xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_inter_mean                                                            float32
# xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_inter_gmean                                                           float32
# xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_inter_hmean                                                           float32
# xentropy_add_lotsof_image_features_lgb719_rf719_inter_mean                                                                                  float32
# xentropy_add_lotsof_image_features_lgb719_rf719_inter_gmean                                                                                 float32
# xentropy_add_lotsof_image_features_lgb719_rf719_inter_hmean                                                                                 float32
# xentropy_add_lotsof_image_features_lgb719_ridge_new_719_inter_mean                                                                          float32
# xentropy_add_lotsof_image_features_lgb719_ridge_new_719_inter_gmean                                                                         float32
# xentropy_add_lotsof_image_features_lgb719_ridge_new_719_inter_hmean                                                                         float32
# xentropy_add_lotsof_image_features_lgb719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean                                 float32
# xentropy_add_lotsof_image_features_lgb719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean                                float32
# xentropy_add_lotsof_image_features_lgb719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean                                float32
# baseline_xgb_719_cgb719_with_categorical_inter_mean                                                                                         float32
# baseline_xgb_719_cgb719_with_categorical_inter_gmean                                                                                        float32
# baseline_xgb_719_cgb719_with_categorical_inter_hmean                                                                                        float32
# baseline_xgb_719_lgb719_goss_append_keypoint_inter_mean                                                                                     float32
# baseline_xgb_719_lgb719_goss_append_keypoint_inter_gmean                                                                                    float32
# baseline_xgb_719_lgb719_goss_append_keypoint_inter_hmean                                                                                    float32
# baseline_xgb_719_rf719_inter_mean                                                                                                           float32
# baseline_xgb_719_rf719_inter_gmean                                                                                                          float32
# baseline_xgb_719_rf719_inter_hmean                                                                                                          float32
# baseline_xgb_719_ridge_new_719_inter_mean                                                                                                   float32
# baseline_xgb_719_ridge_new_719_inter_gmean                                                                                                  float32
# baseline_xgb_719_ridge_new_719_inter_hmean                                                                                                  float32
# baseline_xgb_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean                                                          float32
# baseline_xgb_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean                                                         float32
# baseline_xgb_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean                                                         float32
# cgb719_with_categorical_lgb719_goss_append_keypoint_inter_mean                                                                              float32
# cgb719_with_categorical_lgb719_goss_append_keypoint_inter_gmean                                                                             float32
# cgb719_with_categorical_lgb719_goss_append_keypoint_inter_hmean                                                                             float32
# cgb719_with_categorical_rf719_inter_mean                                                                                                    float32
# cgb719_with_categorical_rf719_inter_gmean                                                                                                   float32
# cgb719_with_categorical_rf719_inter_hmean                                                                                                   float32
# cgb719_with_categorical_ridge_new_719_inter_mean                                                                                            float32
# cgb719_with_categorical_ridge_new_719_inter_gmean                                                                                           float32
# cgb719_with_categorical_ridge_new_719_inter_hmean                                                                                           float32
# cgb719_with_categorical_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean                                                   float32
# cgb719_with_categorical_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean                                                  float32
# cgb719_with_categorical_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean                                                  float32
# lgb719_goss_append_keypoint_rf719_inter_mean                                                                                                float32
# lgb719_goss_append_keypoint_rf719_inter_gmean                                                                                               float32
# lgb719_goss_append_keypoint_rf719_inter_hmean                                                                                               float32
# lgb719_goss_append_keypoint_ridge_new_719_inter_mean                                                                                        float32
# lgb719_goss_append_keypoint_ridge_new_719_inter_gmean                                                                                       float32
# lgb719_goss_append_keypoint_ridge_new_719_inter_hmean                                                                                       float32
# lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean                                               float32
# lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean                                              float32
# lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean                                              float32
# rf719_ridge_new_719_inter_mean                                                                                                              float32
# rf719_ridge_new_719_inter_gmean                                                                                                             float32
# rf719_ridge_new_719_inter_hmean                                                                                                             float32
# rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean                                                                     float32
# rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean                                                                    float32
# rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean                                                                    float32
# ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean                                                             float32
# ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean                                                            float32
# ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean                                                            float32
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_cgb719_with_categorical_inter_mean                                               float32
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_cgb719_with_categorical_inter_gmean                                              float32
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_cgb719_with_categorical_inter_hmean                                              float32
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_cgb719_with_categorical_inter_med                                                float32
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_cgb719_with_categorical_inter_std                                                float32
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_lgb719_goss_append_keypoint_inter_mean                                           float32
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_lgb719_goss_append_keypoint_inter_gmean                                          float32
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_lgb719_goss_append_keypoint_inter_hmean                                          float32
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_lgb719_goss_append_keypoint_inter_med                                            float32
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_lgb719_goss_append_keypoint_inter_std                                            float32
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_rf719_inter_mean                                                                 float32
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_rf719_inter_gmean                                                                float32
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_rf719_inter_hmean                                                                float32
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_rf719_inter_med                                                                  float32
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_rf719_inter_std                                                                  float32
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_ridge_new_719_inter_mean                                                         float32
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_ridge_new_719_inter_gmean                                                        float32
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_ridge_new_719_inter_hmean                                                        float32
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_ridge_new_719_inter_med                                                          float32
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_ridge_new_719_inter_std                                                          float32
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean                float32
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean               float32
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean               float32
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_med                 float32
# xentropy_add_lotsof_image_features_lgb719_baseline_xgb_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_std                 float32
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_lgb719_goss_append_keypoint_inter_mean                                    float32
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_lgb719_goss_append_keypoint_inter_gmean                                   float32
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_lgb719_goss_append_keypoint_inter_hmean                                   float32
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_lgb719_goss_append_keypoint_inter_med                                     float32
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_lgb719_goss_append_keypoint_inter_std                                     float32
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_rf719_inter_mean                                                          float32
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_rf719_inter_gmean                                                         float32
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_rf719_inter_hmean                                                         float32
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_rf719_inter_med                                                           float32
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_rf719_inter_std                                                           float32
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_ridge_new_719_inter_mean                                                  float32
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_ridge_new_719_inter_gmean                                                 float32
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_ridge_new_719_inter_hmean                                                 float32
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_ridge_new_719_inter_med                                                   float32
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_ridge_new_719_inter_std                                                   float32
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean         float32
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean        float32
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean        float32
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_med          float32
# xentropy_add_lotsof_image_features_lgb719_cgb719_with_categorical_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_std          float32
# xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_rf719_inter_mean                                                      float32
# xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_rf719_inter_gmean                                                     float32
# xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_rf719_inter_hmean                                                     float32
# xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_rf719_inter_med                                                       float32
# xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_rf719_inter_std                                                       float32
# xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_ridge_new_719_inter_mean                                              float32
# xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_ridge_new_719_inter_gmean                                             float32
# xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_ridge_new_719_inter_hmean                                             float32
# xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_ridge_new_719_inter_med                                               float32
# xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_ridge_new_719_inter_std                                               float32
# xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean     float32
# xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean    float32
# xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean    float32
# xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_med      float32
# xentropy_add_lotsof_image_features_lgb719_lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_std      float32
# xentropy_add_lotsof_image_features_lgb719_rf719_ridge_new_719_inter_mean                                                                    float32
# xentropy_add_lotsof_image_features_lgb719_rf719_ridge_new_719_inter_gmean                                                                   float32
# xentropy_add_lotsof_image_features_lgb719_rf719_ridge_new_719_inter_hmean                                                                   float32
# xentropy_add_lotsof_image_features_lgb719_rf719_ridge_new_719_inter_med                                                                     float32
# xentropy_add_lotsof_image_features_lgb719_rf719_ridge_new_719_inter_std                                                                     float32
# xentropy_add_lotsof_image_features_lgb719_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean                           float32
# xentropy_add_lotsof_image_features_lgb719_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean                          float32
# xentropy_add_lotsof_image_features_lgb719_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean                          float32
# xentropy_add_lotsof_image_features_lgb719_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_med                            float32
# xentropy_add_lotsof_image_features_lgb719_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_std                            float32
# xentropy_add_lotsof_image_features_lgb719_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean                   float32
# xentropy_add_lotsof_image_features_lgb719_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean                  float32
# xentropy_add_lotsof_image_features_lgb719_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean                  float32
# xentropy_add_lotsof_image_features_lgb719_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_med                    float32
# xentropy_add_lotsof_image_features_lgb719_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_std                    float32
# baseline_xgb_719_cgb719_with_categorical_lgb719_goss_append_keypoint_inter_mean                                                             float32
# baseline_xgb_719_cgb719_with_categorical_lgb719_goss_append_keypoint_inter_gmean                                                            float32
# baseline_xgb_719_cgb719_with_categorical_lgb719_goss_append_keypoint_inter_hmean                                                            float32
# baseline_xgb_719_cgb719_with_categorical_lgb719_goss_append_keypoint_inter_med                                                              float32
# baseline_xgb_719_cgb719_with_categorical_lgb719_goss_append_keypoint_inter_std                                                              float32
# baseline_xgb_719_cgb719_with_categorical_rf719_inter_mean                                                                                   float32
# baseline_xgb_719_cgb719_with_categorical_rf719_inter_gmean                                                                                  float32
# baseline_xgb_719_cgb719_with_categorical_rf719_inter_hmean                                                                                  float32
# baseline_xgb_719_cgb719_with_categorical_rf719_inter_med                                                                                    float32
# baseline_xgb_719_cgb719_with_categorical_rf719_inter_std                                                                                    float32
# baseline_xgb_719_cgb719_with_categorical_ridge_new_719_inter_mean                                                                           float32
# baseline_xgb_719_cgb719_with_categorical_ridge_new_719_inter_gmean                                                                          float32
# baseline_xgb_719_cgb719_with_categorical_ridge_new_719_inter_hmean                                                                          float32
# baseline_xgb_719_cgb719_with_categorical_ridge_new_719_inter_med                                                                            float32
# baseline_xgb_719_cgb719_with_categorical_ridge_new_719_inter_std                                                                            float32
# baseline_xgb_719_cgb719_with_categorical_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean                                  float32
# baseline_xgb_719_cgb719_with_categorical_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean                                 float32
# baseline_xgb_719_cgb719_with_categorical_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean                                 float32
# baseline_xgb_719_cgb719_with_categorical_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_med                                   float32
# baseline_xgb_719_cgb719_with_categorical_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_std                                   float32
# baseline_xgb_719_lgb719_goss_append_keypoint_rf719_inter_mean                                                                               float32
# baseline_xgb_719_lgb719_goss_append_keypoint_rf719_inter_gmean                                                                              float32
# baseline_xgb_719_lgb719_goss_append_keypoint_rf719_inter_hmean                                                                              float32
# baseline_xgb_719_lgb719_goss_append_keypoint_rf719_inter_med                                                                                float32
# baseline_xgb_719_lgb719_goss_append_keypoint_rf719_inter_std                                                                                float32
# baseline_xgb_719_lgb719_goss_append_keypoint_ridge_new_719_inter_mean                                                                       float32
# baseline_xgb_719_lgb719_goss_append_keypoint_ridge_new_719_inter_gmean                                                                      float32
# baseline_xgb_719_lgb719_goss_append_keypoint_ridge_new_719_inter_hmean                                                                      float32
# baseline_xgb_719_lgb719_goss_append_keypoint_ridge_new_719_inter_med                                                                        float32
# baseline_xgb_719_lgb719_goss_append_keypoint_ridge_new_719_inter_std                                                                        float32
# baseline_xgb_719_lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean                              float32
# baseline_xgb_719_lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean                             float32
# baseline_xgb_719_lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean                             float32
# baseline_xgb_719_lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_med                               float32
# baseline_xgb_719_lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_std                               float32
# baseline_xgb_719_rf719_ridge_new_719_inter_mean                                                                                             float32
# baseline_xgb_719_rf719_ridge_new_719_inter_gmean                                                                                            float32
# baseline_xgb_719_rf719_ridge_new_719_inter_hmean                                                                                            float32
# baseline_xgb_719_rf719_ridge_new_719_inter_med                                                                                              float32
# baseline_xgb_719_rf719_ridge_new_719_inter_std                                                                                              float32
# baseline_xgb_719_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean                                                    float32
# baseline_xgb_719_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean                                                   float32
# baseline_xgb_719_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean                                                   float32
# baseline_xgb_719_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_med                                                     float32
# baseline_xgb_719_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_std                                                     float32
# baseline_xgb_719_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean                                            float32
# baseline_xgb_719_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean                                           float32
# baseline_xgb_719_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean                                           float32
# baseline_xgb_719_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_med                                             float32
# baseline_xgb_719_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_std                                             float32
# cgb719_with_categorical_lgb719_goss_append_keypoint_rf719_inter_mean                                                                        float32
# cgb719_with_categorical_lgb719_goss_append_keypoint_rf719_inter_gmean                                                                       float32
# cgb719_with_categorical_lgb719_goss_append_keypoint_rf719_inter_hmean                                                                       float32
# cgb719_with_categorical_lgb719_goss_append_keypoint_rf719_inter_med                                                                         float32
# cgb719_with_categorical_lgb719_goss_append_keypoint_rf719_inter_std                                                                         float32
# cgb719_with_categorical_lgb719_goss_append_keypoint_ridge_new_719_inter_mean                                                                float32
# cgb719_with_categorical_lgb719_goss_append_keypoint_ridge_new_719_inter_gmean                                                               float32
# cgb719_with_categorical_lgb719_goss_append_keypoint_ridge_new_719_inter_hmean                                                               float32
# cgb719_with_categorical_lgb719_goss_append_keypoint_ridge_new_719_inter_med                                                                 float32
# cgb719_with_categorical_lgb719_goss_append_keypoint_ridge_new_719_inter_std                                                                 float32
# cgb719_with_categorical_lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean                       float32
# cgb719_with_categorical_lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean                      float32
# cgb719_with_categorical_lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean                      float32
# cgb719_with_categorical_lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_med                        float32
# cgb719_with_categorical_lgb719_goss_append_keypoint_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_std                        float32
# cgb719_with_categorical_rf719_ridge_new_719_inter_mean                                                                                      float32
# cgb719_with_categorical_rf719_ridge_new_719_inter_gmean                                                                                     float32
# cgb719_with_categorical_rf719_ridge_new_719_inter_hmean                                                                                     float32
# cgb719_with_categorical_rf719_ridge_new_719_inter_med                                                                                       float32
# cgb719_with_categorical_rf719_ridge_new_719_inter_std                                                                                       float32
# cgb719_with_categorical_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean                                             float32
# cgb719_with_categorical_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean                                            float32
# cgb719_with_categorical_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean                                            float32
# cgb719_with_categorical_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_med                                              float32
# cgb719_with_categorical_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_std                                              float32
# cgb719_with_categorical_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean                                     float32
# cgb719_with_categorical_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean                                    float32
# cgb719_with_categorical_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean                                    float32
# cgb719_with_categorical_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_med                                      float32
# cgb719_with_categorical_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_std                                      float32
# lgb719_goss_append_keypoint_rf719_ridge_new_719_inter_mean                                                                                  float32
# lgb719_goss_append_keypoint_rf719_ridge_new_719_inter_gmean                                                                                 float32
# lgb719_goss_append_keypoint_rf719_ridge_new_719_inter_hmean                                                                                 float32
# lgb719_goss_append_keypoint_rf719_ridge_new_719_inter_med                                                                                   float32
# lgb719_goss_append_keypoint_rf719_ridge_new_719_inter_std                                                                                   float32
# lgb719_goss_append_keypoint_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean                                         float32
# lgb719_goss_append_keypoint_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean                                        float32
# lgb719_goss_append_keypoint_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean                                        float32
# lgb719_goss_append_keypoint_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_med                                          float32
# lgb719_goss_append_keypoint_rf719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_std                                          float32
# lgb719_goss_append_keypoint_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean                                 float32
# lgb719_goss_append_keypoint_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean                                float32
# lgb719_goss_append_keypoint_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean                                float32
# lgb719_goss_append_keypoint_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_med                                  float32
# lgb719_goss_append_keypoint_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_std                                  float32
# rf719_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_mean                                                       float32
# rf719_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_gmean                                                      float32
# rf719_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_hmean                                                      float32
# rf719_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_med                                                        float32
# rf719_ridge_new_719_selftrained_bigru_conv1d_merged_with_image_adv_719_rnn_inter_std                                                        float32
# dtypes: float32(250)
# memory usage: 1.4 GB

# %%
with open('meta_train_719.pickle', 'wb') as handle:
    pickle.dump(train, handle)
    
with open('meta_test_719.pickle', 'wb') as handle:
    pickle.dump(test, handle)

# %% [markdown]
# ## Meta Model Tuning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import gc; gc.enable()
import pickle
from tqdm import tqdm
import warnings ; warnings.filterwarnings('ignore')
import os
from GridSearcher import data_loader, model_loader, fit_params, get_oof_predictions, clip_rmse

# %%
SEED=719
train_y = pd.read_csv("regression_target.csv").deal_probability.values

# %%
with open('meta_train_719.pickle', 'rb') as handle:
    train = pickle.load(handle)
    
with open('meta_test_719.pickle', 'rb') as handle:
    test = pickle.load(handle)

# %% [markdown]
# ### Lightgbm-gbdt

# %%
ml = model_loader(model_type='lgb')

# %%
default_params = {
    'boosting_type':'gbdt', 
    'num_leaves':31, 
    'max_depth':5, 
    'learning_rate':0.1, 
    'n_estimators':100, 
    'min_split_gain':0.0, 
    'min_child_weight':0.001, 
    'min_child_samples':20, 
    'subsample':1.,  
    'colsample_bytree':1., 
    'reg_alpha':2.0, 
    'reg_lambda':0.0, 
    'random_state':SEED, 
    'n_jobs': 4
}

fit_param = None

try_params = {
    'min_split_gain': [.0, .1, .2, .3, .4]
}

fit_params(train, train_y, ml, default_params, try_params, fit_params=fit_param, seed=SEED, use_eval_set=False)
# Out:
# {'min_split_gain': 0.0} train loss: 0.207978, valid loss:0.208974, loss_diff:0.000996
# {'min_split_gain': 0.0} train loss: 0.207808, valid loss:0.209675, loss_diff:0.001867
# {'min_split_gain': 0.0} train loss: 0.208046, valid loss:0.208600, loss_diff:0.000554
# {'min_split_gain': 0.0} train loss: 0.207981, valid loss:0.208823, loss_diff:0.000843
# {'min_split_gain': 0.0} train loss: 0.207785, valid loss:0.209536, loss_diff:0.001751
# =================>{'min_split_gain': 0.0} loss:0.209122
# {'min_split_gain': 0.1} train loss: 0.207993, valid loss:0.208984, loss_diff:0.000991
# {'min_split_gain': 0.1} train loss: 0.207808, valid loss:0.209692, loss_diff:0.001884
# {'min_split_gain': 0.1} train loss: 0.208039, valid loss:0.208583, loss_diff:0.000544
# {'min_split_gain': 0.1} train loss: 0.207969, valid loss:0.208843, loss_diff:0.000874
# {'min_split_gain': 0.1} train loss: 0.207823, valid loss:0.209519, loss_diff:0.001695
# =================>{'min_split_gain': 0.1} loss:0.209124
# {'min_split_gain': 0.2} train loss: 0.207997, valid loss:0.208965, loss_diff:0.000967
# {'min_split_gain': 0.2} train loss: 0.207846, valid loss:0.209689, loss_diff:0.001843
# {'min_split_gain': 0.2} train loss: 0.208086, valid loss:0.208617, loss_diff:0.000531
# {'min_split_gain': 0.2} train loss: 0.208017, valid loss:0.208843, loss_diff:0.000826
# {'min_split_gain': 0.2} train loss: 0.207842, valid loss:0.209579, loss_diff:0.001738
# =================>{'min_split_gain': 0.2} loss:0.209139
# {'min_split_gain': 0.3} train loss: 0.208034, valid loss:0.208977, loss_diff:0.000942
# {'min_split_gain': 0.3} train loss: 0.207907, valid loss:0.209722, loss_diff:0.001816
# {'min_split_gain': 0.3} train loss: 0.208118, valid loss:0.208632, loss_diff:0.000513
# {'min_split_gain': 0.3} train loss: 0.208046, valid loss:0.208849, loss_diff:0.000803
# {'min_split_gain': 0.3} train loss: 0.207868, valid loss:0.209589, loss_diff:0.001721
# =================>{'min_split_gain': 0.3} loss:0.209154
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-47b310750570> in <module>()
#      22 }
#      23
# ---> 24 fit_params(train, train_y, ml, default_params, try_params, fit_params=fit_param, seed=SEED, use_eval_set=False)
#
# D:\Kaggle Competitions\Kaggle-avito-demand-prediction\GridSearcher.py in fit_params(X, y, model_loader, default_params, try_params, use_eval_set, fit_params, seed, loss_func, predict_proba)
#     303                     model.fit(tr_X, tr_y, **fit_params)
#     304             else:
# --> 305                 model.fit(tr_X, tr_y)
#     306
#     307             if predict_proba:
#
# ~\Anaconda3\lib\site-packages\lightgbm\sklearn.py in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_init_score, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     610                                        verbose=verbose, feature_name=feature_name,
#     611                                        categorical_feature=categorical_feature,
# --> 612                                        callbacks=callbacks)
#     613         return self
#     614
#
# ~\Anaconda3\lib\site-packages\lightgbm\sklearn.py in fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_init_score, eval_group, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     457                               verbose_eval=verbose, feature_name=feature_name,
#     458                               categorical_feature=categorical_feature,
# --> 459                               callbacks=callbacks)
#     460
#     461         if evals_result:
#
# ~\Anaconda3\lib\site-packages\lightgbm\engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     197                                     evaluation_result_list=None))
#     198
# --> 199         booster.update(fobj=fobj)
#     200
#     201         evaluation_result_list = []
#
# ~\Anaconda3\lib\site-packages\lightgbm\basic.py in update(self, train_set, fobj)
#    1437             _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#    1438                 self.handle,
# -> 1439                 ctypes.byref(is_finished)))
#    1440             self.__is_predicted_cur_iter = [False for _ in range_(self.__num_dataset)]
#    1441             return is_finished.value == 1
#
# KeyboardInterrupt:

# %%
'''
best 
{'min_split_gain': 0.1} train loss: 0.208348, valid loss:0.209236, loss_diff:0.000887
{'min_split_gain': 0.1} train loss: 0.208166, valid loss:0.209885, loss_diff:0.001718
{'min_split_gain': 0.1} train loss: 0.208426, valid loss:0.208832, loss_diff:0.000405
{'min_split_gain': 0.1} train loss: 0.208379, valid loss:0.208949, loss_diff:0.000570
{'min_split_gain': 0.1} train loss: 0.208165, valid loss:0.209724, loss_diff:0.001559
=================>{'min_split_gain': 0.1} loss:0.209325
'''
# Out:
# "\nbest \n{'min_split_gain': 0.1} train loss: 0.208348, valid loss:0.209236, loss_diff:0.000887\n{'min_split_gain': 0.1} train loss: 0.208166, valid loss:0.209885, loss_diff:0.001718\n{'min_split_gain': 0.1} train loss: 0.208426, valid loss:0.208832, loss_diff:0.000405\n{'min_split_gain': 0.1} train loss: 0.208379, valid loss:0.208949, loss_diff:0.000570\n{'min_split_gain': 0.1} train loss: 0.208165, valid loss:0.209724, loss_diff:0.001559\n=================>{'min_split_gain': 0.1} loss:0.209325\n"

# %%
default_params = {
    'boosting_type':'gbdt', 
    'num_leaves':31, 
    'max_depth':5, 
    'learning_rate':0.1, 
    'n_estimators':100, 
    'min_split_gain':0.0, 
    'min_child_weight':0.001, 
    'min_child_samples':20, 
    'subsample':1.,  
    'colsample_bytree':1., 
    'reg_alpha':2.0, 
    'reg_lambda':0.0, 
    'random_state':SEED, 
    'n_jobs': 4
}

fit_param = None

try_params = {
    'colsample_bytree':[i/10.0 for i in range(6,11)]
}

fit_params(train, train_y, ml, default_params, try_params, fit_params=fit_param, seed=SEED, use_eval_set=False)

# %%
default_params = {
    'boosting_type':'gbdt', 
    'num_leaves':31, 
    'max_depth':5, 
    'learning_rate':0.1, 
    'n_estimators':100, 
    'min_split_gain':0.1, 
    'min_child_weight':0.001, 
    'min_child_samples':20, 
    'subsample':1.,  
    'colsample_bytree':1., 
    'reg_alpha':2.0, 
    'reg_lambda':0.0, 
    'random_state':SEED, 
    'n_jobs': 3
}


fit_param = None

try_params = {
    'subsample':[i/10.0 for i in range(6,11)]
}

fit_params(train, train_y, ml, default_params, try_params, fit_params=fit_param, seed=SEED, use_eval_set=False)
# Out:
# {'subsample': 0.6} train loss: 0.208383, valid loss:0.209283, loss_diff:0.000900
# {'subsample': 0.6} train loss: 0.208222, valid loss:0.209865, loss_diff:0.001642
# {'subsample': 0.6} train loss: 0.208485, valid loss:0.208844, loss_diff:0.000359
# {'subsample': 0.6} train loss: 0.208434, valid loss:0.208999, loss_diff:0.000565
# {'subsample': 0.6} train loss: 0.208252, valid loss:0.209756, loss_diff:0.001504
# =================>{'subsample': 0.6} loss:0.209349
# {'subsample': 0.7} train loss: 0.208363, valid loss:0.209219, loss_diff:0.000857
# {'subsample': 0.7} train loss: 0.208175, valid loss:0.209866, loss_diff:0.001690
# {'subsample': 0.7} train loss: 0.208406, valid loss:0.208786, loss_diff:0.000380
# {'subsample': 0.7} train loss: 0.208416, valid loss:0.209000, loss_diff:0.000583
# {'subsample': 0.7} train loss: 0.208231, valid loss:0.209730, loss_diff:0.001500
# =================>{'subsample': 0.7} loss:0.209320
# {'subsample': 0.8} train loss: 0.208352, valid loss:0.209221, loss_diff:0.000869
# {'subsample': 0.8} train loss: 0.208169, valid loss:0.209877, loss_diff:0.001707
# {'subsample': 0.8} train loss: 0.208429, valid loss:0.208823, loss_diff:0.000394
# {'subsample': 0.8} train loss: 0.208391, valid loss:0.209028, loss_diff:0.000637
# {'subsample': 0.8} train loss: 0.208214, valid loss:0.209759, loss_diff:0.001545
# =================>{'subsample': 0.8} loss:0.209341
# {'subsample': 0.9} train loss: 0.208381, valid loss:0.209272, loss_diff:0.000891
# {'subsample': 0.9} train loss: 0.208194, valid loss:0.209908, loss_diff:0.001714
# {'subsample': 0.9} train loss: 0.208463, valid loss:0.208885, loss_diff:0.000423
# {'subsample': 0.9} train loss: 0.208370, valid loss:0.208996, loss_diff:0.000626
# {'subsample': 0.9} train loss: 0.208210, valid loss:0.209740, loss_diff:0.001530
# =================>{'subsample': 0.9} loss:0.209360
# {'subsample': 1.0} train loss: 0.208348, valid loss:0.209236, loss_diff:0.000887
# {'subsample': 1.0} train loss: 0.208166, valid loss:0.209885, loss_diff:0.001718
# {'subsample': 1.0} train loss: 0.208426, valid loss:0.208832, loss_diff:0.000405
# {'subsample': 1.0} train loss: 0.208379, valid loss:0.208949, loss_diff:0.000570
# {'subsample': 1.0} train loss: 0.208165, valid loss:0.209724, loss_diff:0.001559
# =================>{'subsample': 1.0} loss:0.209325
# Best params: {'subsample': 0.7} 	best loss: 0.209320113891
#                 param  val_loss_mean  val_loss_std
# 0  {'subsample': 0.6}       0.209349      0.000403
# 1  {'subsample': 0.7}       0.209320      0.000416
# 2  {'subsample': 0.8}       0.209341      0.000410
# 3  {'subsample': 0.9}       0.209360      0.000403
# 4  {'subsample': 1.0}       0.209325      0.000416

# %%
default_params = {
    'boosting_type':'gbdt', 
    'num_leaves':31, 
    'max_depth':5, 
    'learning_rate':0
 
    'random_state':SEED, 
    'n_jobs': 3
}

fit_param = {
    'early_stopping_rounds': 50,
    'verbose': 100,
    'eval_metric': 'rmse'
}

_, ret_test, _ = get_oof_predictions(train, train_y, test, ml, 
                                     default_params, seed=19, fit_params=fit_param, use_eval_set=True)

# %%
test_df = pd.read_csv("test.csv", usecols=['item_id'])
pd.DataFrame(np.clip(ret_test,0,1), 
             index=test_df.item_id,
             columns=['deal_probability']).to_csv('lgb_meta_no_bagging_exclude_knn.csv')

# %% [markdown]
# ### Lightgbm-dart

# %%
default_params = {
    'boosting_type':'dart', 
    'num_leaves':31, 
    'max_depth':5, 
    'learning_rate':0.1, 
    'n_estimators':100, 
    'min_split_gain':0.0, 
    'min_child_weight':0.001, 
    'min_child_samples':20, 
    'subsample':1.,  
    'colsample_bytree':1., 
    'reg_alpha':2.0, 
    'reg_lambda':0.0, 
    'random_state':SEED, 
    'n_jobs': 3
}

fit_param = None

try_params = {
    'min_split_gain': [.0, .1, .2, .3, .4]
}

fit_params(train, train_y, ml, default_params, try_params, fit_params=fit_param, seed=SEED, use_eval_set=False)
# Out:
# {'min_split_gain': 0.0} train loss: 0.213927, valid loss:0.214264, loss_diff:0.000337
# {'min_split_gain': 0.0} train loss: 0.213748, valid loss:0.215104, loss_diff:0.001356
# {'min_split_gain': 0.0} train loss: 0.214077, valid loss:0.213627, loss_diff:-0.000450
# {'min_split_gain': 0.0} train loss: 0.214023, valid loss:0.213778, loss_diff:-0.000245
# {'min_split_gain': 0.0} train loss: 0.213804, valid loss:0.214721, loss_diff:0.000917
# =================>{'min_split_gain': 0.0} loss:0.214299
# {'min_split_gain': 0.1} train loss: 0.213920, valid loss:0.214252, loss_diff:0.000331
# {'min_split_gain': 0.1} train loss: 0.213755, valid loss:0.215107, loss_diff:0.001352
# {'min_split_gain': 0.1} train loss: 0.214055, valid loss:0.213606, loss_diff:-0.000449
# {'min_split_gain': 0.1} train loss: 0.214021, valid loss:0.213776, loss_diff:-0.000245
# {'min_split_gain': 0.1} train loss: 0.213790, valid loss:0.214729, loss_diff:0.000938
# =================>{'min_split_gain': 0.1} loss:0.214294
# {'min_split_gain': 0.2} train loss: 0.213925, valid loss:0.214274, loss_diff:0.000349
# {'min_split_gain': 0.2} train loss: 0.213742, valid loss:0.215098, loss_diff:0.001357
# {'min_split_gain': 0.2} train loss: 0.214065, valid loss:0.213638, loss_diff:-0.000427
# {'min_split_gain': 0.2} train loss: 0.214018, valid loss:0.213760, loss_diff:-0.000258
# {'min_split_gain': 0.2} train loss: 0.213804, valid loss:0.214729, loss_diff:0.000925
# =================>{'min_split_gain': 0.2} loss:0.214300
# {'min_split_gain': 0.3} train loss: 0.213934, valid loss:0.214260, loss_diff:0.000327
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-debc7f84c536> in <module>()
#      22 }
#      23
# ---> 24 fit_params(train, train_y, ml, default_params, try_params, fit_params=fit_param, seed=SEED, use_eval_set=False)
#
# D:\Kaggle Competitions\Kaggle-avito-demand-prediction\GridSearcher.py in fit_params(X, y, model_loader, default_params, try_params, use_eval_set, fit_params, seed, loss_func, predict_proba)
#     303                     model.fit(tr_X, tr_y, **fit_params)
#     304             else:
# --> 305                 model.fit(tr_X, tr_y)
#     306
#     307             if predict_proba:
#
# ~\Anaconda3\lib\site-packages\lightgbm\sklearn.py in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_init_score, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     610                                        verbose=verbose, feature_name=feature_name,
#     611                                        categorical_feature=categorical_feature,
# --> 612                                        callbacks=callbacks)
#     613         return self
#     614
#
# ~\Anaconda3\lib\site-packages\lightgbm\sklearn.py in fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_init_score, eval_group, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     457                               verbose_eval=verbose, feature_name=feature_name,
#     458                               categorical_feature=categorical_feature,
# --> 459                               callbacks=callbacks)
#     460
#     461         if evals_result:
#
# ~\Anaconda3\lib\site-packages\lightgbm\engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     197                                     evaluation_result_list=None))
#     198
# --> 199         booster.update(fobj=fobj)
#     200
#     201         evaluation_result_list = []
#
# ~\Anaconda3\lib\site-packages\lightgbm\basic.py in update(self, train_set, fobj)
#    1437             _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#    1438                 self.handle,
# -> 1439                 ctypes.byref(is_finished)))
#    1440             self.__is_predicted_cur_iter = [False for _ in range_(self.__num_dataset)]
#    1441             return is_finished.value == 1
#
# KeyboardInterrupt:

# %%
default_params = {
    'boosting_type':'dart', 
    'num_leaves':31, 
    'max_depth':5, 
    'learning_rate':0.1, 
    'n_estimators':100, 
    'min_split_gain':0.3, 
    'min_child_weight':0.001, 
    'min_child_samples':20, 
    'subsample':1.,  
    'colsample_bytree':1., 
    'reg_alpha':2.0, 
    'reg_lambda':0.0, 
    'random_state':SEED, 
    'n_jobs': 3
}

fit_param = None

try_params = {
    'colsample_bytree':[i/10.0 for i in range(6,11)]
}

fit_params(train, train_y, ml, default_params, try_params, fit_params=fit_param, seed=SEED, use_eval_set=False)
# Out:
# {'colsample_bytree': 0.6} train loss: 0.212777, valid loss:0.212907, loss_diff:0.000130
# {'colsample_bytree': 0.6} train loss: 0.212682, valid loss:0.213379, loss_diff:0.000696
# {'colsample_bytree': 0.6} train loss: 0.212666, valid loss:0.213448, loss_diff:0.000782
# {'colsample_bytree': 0.6} train loss: 0.212721, valid loss:0.213123, loss_diff:0.000403
# {'colsample_bytree': 0.6} train loss: 0.212778, valid loss:0.212892, loss_diff:0.000114
# =================>{'colsample_bytree': 0.6} loss:0.213150
# {'colsample_bytree': 0.7} train loss: 0.212761, valid loss:0.212934, loss_diff:0.000172
# {'colsample_bytree': 0.7} train loss: 0.212644, valid loss:0.213358, loss_diff:0.000714
# {'colsample_bytree': 0.7} train loss: 0.212643, valid loss:0.213420, loss_diff:0.000777
# {'colsample_bytree': 0.7} train loss: 0.212692, valid loss:0.213109, loss_diff:0.000417
# {'colsample_bytree': 0.7} train loss: 0.212771, valid loss:0.212889, loss_diff:0.000118
# =================>{'colsample_bytree': 0.7} loss:0.213142
# {'colsample_bytree': 0.8} train loss: 0.212740, valid loss:0.212878, loss_diff:0.000138
# {'colsample_bytree': 0.8} train loss: 0.212634, valid loss:0.213355, loss_diff:0.000721
# {'colsample_bytree': 0.8} train loss: 0.212615, valid loss:0.213405, loss_diff:0.000790
# {'colsample_bytree': 0.8} train loss: 0.212686, valid loss:0.213088, loss_diff:0.000401
# {'colsample_bytree': 0.8} train loss: 0.212766, valid loss:0.212889, loss_diff:0.000123
# =================>{'colsample_bytree': 0.8} loss:0.213123
# {'colsample_bytree': 0.9} train loss: 0.212744, valid loss:0.212931, loss_diff:0.000187
# {'colsample_bytree': 0.9} train loss: 0.212640, valid loss:0.213351, loss_diff:0.000711
# {'colsample_bytree': 0.9} train loss: 0.212613, valid loss:0.213417, loss_diff:0.000803
# {'colsample_bytree': 0.9} train loss: 0.212687, valid loss:0.213103, loss_diff:0.000417
# {'colsample_bytree': 0.9} train loss: 0.212759, valid loss:0.212897, loss_diff:0.000139
# =================>{'colsample_bytree': 0.9} loss:0.213140
# {'colsample_bytree': 1.0} train loss: 0.212707, valid loss:0.212882, loss_diff:0.000174
# {'colsample_bytree': 1.0} train loss: 0.212610, valid loss:0.213326, loss_diff:0.000716
# {'colsample_bytree': 1.0} train loss: 0.212597, valid loss:0.213393, loss_diff:0.000795
# {'colsample_bytree': 1.0} train loss: 0.212668, valid loss:0.213069, loss_diff:0.000401
# {'colsample_bytree': 1.0} train loss: 0.212739, valid loss:0.212878, loss_diff:0.000139
# =================>{'colsample_bytree': 1.0} loss:0.213110
# Best params: {'colsample_bytree': 1.0} 	best loss: 0.213109551841
#                        param  val_loss_mean  val_loss_std
# 0  {'colsample_bytree': 0.6}       0.213150      0.000231
# 1  {'colsample_bytree': 0.7}       0.213142      0.000216
# 2  {'colsample_bytree': 0.8}       0.213123      0.000223
# 3  {'colsample_bytree': 0.9}       0.213140      0.000212
# 4  {'colsample_bytree': 1.0}       0.213110      0.000217

# %%
default_params = {
    'boosting_type':'dart', 
    'num_leaves':31, 
    'max_depth':5, 
    'learning_rate':0.1, 
    'n_estimators':100, 
    'min_split_gain':0.3, 
    'min_child_weight':0.001, 
    'min_child_samples':20, 
    'subsample':1.,  
    'colsample_bytree':1., 
    'reg_alpha':2.0, 
    'reg_lambda':0.0, 
    'random_state':SEED, 
    'n_jobs': 3
}

fit_param = None

try_params = {
    'subsample':[i/10.0 for i in range(6,11)]
}

fit_params(train, train_y, ml, default_params, try_params, fit_params=fit_param, seed=SEED, use_eval_set=False)
# Out:
# {'subsample': 0.6} train loss: 0.212709, valid loss:0.212853, loss_diff:0.000144
# {'subsample': 0.6} train loss: 0.212645, valid loss:0.213329, loss_diff:0.000684
# {'subsample': 0.6} train loss: 0.212630, valid loss:0.213384, loss_diff:0.000754
# {'subsample': 0.6} train loss: 0.212655, valid loss:0.213066, loss_diff:0.000410
# {'subsample': 0.6} train loss: 0.212758, valid loss:0.212853, loss_diff:0.000095
# =================>{'subsample': 0.6} loss:0.213097
# {'subsample': 0.7} train loss: 0.212711, valid loss:0.212867, loss_diff:0.000157
# {'subsample': 0.7} train loss: 0.212632, valid loss:0.213330, loss_diff:0.000698
# {'subsample': 0.7} train loss: 0.212620, valid loss:0.213375, loss_diff:0.000755
# {'subsample': 0.7} train loss: 0.212664, valid loss:0.213054, loss_diff:0.000390
# {'subsample': 0.7} train loss: 0.212737, valid loss:0.212844, loss_diff:0.000107
# =================>{'subsample': 0.7} loss:0.213094
# {'subsample': 0.8} train loss: 0.212731, valid loss:0.212885, loss_diff:0.000154
# {'subsample': 0.8} train loss: 0.212635, valid loss:0.213348, loss_diff:0.000713
# {'subsample': 0.8} train loss: 0.212602, valid loss:0.213379, loss_diff:0.000777
# {'subsample': 0.8} train loss: 0.212661, valid loss:0.213069, loss_diff:0.000408
# {'subsample': 0.8} train loss: 0.212738, valid loss:0.212860, loss_diff:0.000122
# =================>{'subsample': 0.8} loss:0.213108
# {'subsample': 0.9} train loss: 0.212753, valid loss:0.212929, loss_diff:0.000176
# {'subsample': 0.9} train loss: 0.212634, valid loss:0.213344, loss_diff:0.000710
# {'subsample': 0.9} train loss: 0.212616, valid loss:0.213407, loss_diff:0.000791
# {'subsample': 0.9} train loss: 0.212685, valid loss:0.213092, loss_diff:0.000407
# {'subsample': 0.9} train loss: 0.212733, valid loss:0.212856, loss_diff:0.000123
# =================>{'subsample': 0.9} loss:0.213126
# {'subsample': 1.0} train loss: 0.212707, valid loss:0.212882, loss_diff:0.000174
# {'subsample': 1.0} train loss: 0.212610, valid loss:0.213326, loss_diff:0.000716
# {'subsample': 1.0} train loss: 0.212597, valid loss:0.213393, loss_diff:0.000795
# {'subsample': 1.0} train loss: 0.212668, valid loss:0.213069, loss_diff:0.000401
# {'subsample': 1.0} train loss: 0.212739, valid loss:0.212878, loss_diff:0.000139
# =================>{'subsample': 1.0} loss:0.213110
# Best params: {'subsample': 0.7} 	best loss: 0.213094093686
#                 param  val_loss_mean  val_loss_std
# 0  {'subsample': 0.6}       0.213097      0.000226
# 1  {'subsample': 0.7}       0.213094      0.000223
# 2  {'subsample': 0.8}       0.213108      0.000221
# 3  {'subsample': 0.9}       0.213126      0.000219
# 4  {'subsample': 1.0}       0.213110      0.000217

# %%
default_params = {
    'boosting_type':'dart', 
    'num_leaves':31, 
    'max_depth':5, 
    'learning_rate':0.1, 
    'n_estimators':100, 
    'min_split_gain':0.3, 
    'min_child_weight':0.001, 
    'min_child_samples':20, 
    'subsample':.7,  
    'colsample_bytree':1., 
    'reg_alpha':2.0, 
    'reg_lambda':0.0, 
    'random_state':SEED, 
    'n_jobs': 3
}

fit_param = None

try_params = {
    'reg_alpha':[1.0, 1.5, 2.0, 2.5, 3.0]
}

fit_params(train, train_y, ml, default_params, try_params, fit_params=fit_param, seed=SEED, use_eval_set=False)
# Out:
# {'reg_alpha': 1.0} train loss: 0.212702, valid loss:0.212864, loss_diff:0.000162
# {'reg_alpha': 1.0} train loss: 0.212614, valid loss:0.213305, loss_diff:0.000691
# {'reg_alpha': 1.0} train loss: 0.212582, valid loss:0.213371, loss_diff:0.000788
# {'reg_alpha': 1.0} train loss: 0.212675, valid loss:0.213072, loss_diff:0.000397
# {'reg_alpha': 1.0} train loss: 0.212702, valid loss:0.212821, loss_diff:0.000118
# =================>{'reg_alpha': 1.0} loss:0.213086
# {'reg_alpha': 1.5} train loss: 0.212732, valid loss:0.212871, loss_diff:0.000139
# {'reg_alpha': 1.5} train loss: 0.212631, valid loss:0.213312, loss_diff:0.000681
# {'reg_alpha': 1.5} train loss: 0.212605, valid loss:0.213374, loss_diff:0.000770
# {'reg_alpha': 1.5} train loss: 0.212669, valid loss:0.213057, loss_diff:0.000388
# {'reg_alpha': 1.5} train loss: 0.212743, valid loss:0.212854, loss_diff:0.000111
# =================>{'reg_alpha': 1.5} loss:0.213093
# {'reg_alpha': 2.0} train loss: 0.212711, valid loss:0.212867, loss_diff:0.000157
# {'reg_alpha': 2.0} train loss: 0.212632, valid loss:0.213330, loss_diff:0.000698
# {'reg_alpha': 2.0} train loss: 0.212620, valid loss:0.213375, loss_diff:0.000755
# {'reg_alpha': 2.0} train loss: 0.212664, valid loss:0.213054, loss_diff:0.000390
# {'reg_alpha': 2.0} train loss: 0.212737, valid loss:0.212844, loss_diff:0.000107
# =================>{'reg_alpha': 2.0} loss:0.213094
# {'reg_alpha': 2.5} train loss: 0.212723, valid loss:0.212877, loss_diff:0.000154
# {'reg_alpha': 2.5} train loss: 0.212632, valid loss:0.213304, loss_diff:0.000672
# {'reg_alpha': 2.5} train loss: 0.212617, valid loss:0.213390, loss_diff:0.000773
# {'reg_alpha': 2.5} train loss: 0.212677, valid loss:0.213087, loss_diff:0.000410
# {'reg_alpha': 2.5} train loss: 0.212740, valid loss:0.212861, loss_diff:0.000122
# =================>{'reg_alpha': 2.5} loss:0.213104
# {'reg_alpha': 3.0} train loss: 0.212738, valid loss:0.212883, loss_diff:0.000145
# {'reg_alpha': 3.0} train loss: 0.212641, valid loss:0.213324, loss_diff:0.000683
# {'reg_alpha': 3.0} train loss: 0.212635, valid loss:0.213402, loss_diff:0.000767
# {'reg_alpha': 3.0} train loss: 0.212694, valid loss:0.213084, loss_diff:0.000390
# {'reg_alpha': 3.0} train loss: 0.212756, valid loss:0.212859, loss_diff:0.000103
# =================>{'reg_alpha': 3.0} loss:0.213110
# Best params: {'reg_alpha': 1.0} 	best loss: 0.213086329661
#                 param  val_loss_mean  val_loss_std
# 0  {'reg_alpha': 1.0}       0.213086      0.000223
# 1  {'reg_alpha': 1.5}       0.213093      0.000217
# 2  {'reg_alpha': 2.0}       0.213094      0.000223
# 3  {'reg_alpha': 2.5}       0.213104      0.000216
# 4  {'reg_alpha': 3.0}       0.213110      0.000222

# %%
default_params = {
    'boosting_type':'dart', 
    'num_leaves':31, 
    'max_depth':5, 
    'learning_rate':0.1, 
    'n_estimators':100, 
    'min_split_gain':0.3, 
    'min_child_weight':0.001, 
    'min_child_samples':20, 
    'subsample':.7,  
    'colsample_bytree':1., 
    'reg_alpha':1.0, 
    'reg_lambda':0.0, 
    'random_state':SEED, 
    'n_jobs': 3
}

fit_param = None

try_params = {
    'reg_lambda':[i/10.0 for i in range(0,11,1)]
}

fit_params(train, train_y, ml, default_params, try_params, fit_params=fit_param, seed=SEED, use_eval_set=False)
# Out:
# {

    'max_depth':5, 
    'learning_rate':0.1, 
    'n_estimators':100, 
    'gamma':0.0, 
    'min_child_weight':0.001,
    'subsample':1.,  
    'colsample_bytree':1., 
    'reg_alpha':2., 
    'reg_lambda':0.0, 
    'random_state':SEED, 
    'n_jobs': 3
}

fit_param = None

try_params = {
    'min_child_weight':[0.001, 0.1, 2, 4, 8]
}

fit_params(train, train_y, ml, default_params, try_params, fit_params=fit_param, seed=SEED, use_eval_set=False)

# %%
ml = model_loader(model_type='xgb')

default_params = {
    'booster':'gbtree', 
    'max_depth':5, 
    'learning_rate':0.1, 
    'n_estimators':100, 
    'gamma':0.0, 
    'min_child_weight':0.001,
    'subsample':1.,  
    'colsample_bytree':1., 
    'reg_alpha':2., 
    'reg_lambda':0.0, 
    'random_state':SEED, 
    'n_jobs': 3
}

fit_param = None

try_params = {
    'gamma':[.0, .1, .2, .3, .4]
}

fit_params(train, train_y, ml, default_params, try_params, fit_params=fit_param, seed=SEED, use_eval_set=False)

# %%
ml = model_loader(model_type='xgb')

default_params = {
    'booster':'gbtree', 
    'max_depth':5, 
    'learning_rate':0.1, 
    'n_estimators':100, 
    'gamma':0.0, 
    'min_child_weight':0.001,
    'subsample':1.,  
    'colsample_bytree':1., 
    'reg_alpha':2., 
    'reg_lambda':0.0, 
    'random_state':SEED, 
    'n_jobs': 3
}

fit_param = None

try_params = {
    'colsample_bytree':[i/10.0 for i in range(6,11)]
}

fit_params(train, train_y, ml, default_params, try_params, fit_params=fit_param, seed=SEED, use_eval_set=False)

# %%
ml = model_loader(model_type='xgb')

default_params = {
    'booster':'gbtree', 
    'max_depth':5, 
    'learning_rate':0.1, 
    'n_estimators':100, 
    'gamma':0.0, 
    'min_child_weight':0.001,
    'subsample':1.,  
    'colsample_bytree':1., 
    'reg_alpha':2., 
    'reg_lambda':0.0, 
    'random_state':SEED, 
    'n_jobs': 3
}

fit_param = None

try_params = {
    'subsample':[i/10.0 for i in range(6,11)]
}

fit_params(train, train_y, ml, default_params, try_params, fit_params=fit_param, seed=SEED, use_eval_set=False)

# %%
ml = model_loader(model_type='xgb')

default_params = {
    'booster':'gbtree', 
    'max_depth':5, 
    'learning_rate':0.1, 
    'n_estimators':100, 
    'gamma':0.0, 
    'min_child_weight':0.001,
    'subsample':1.,  
    'colsample_bytree':1., 
    'reg_alpha':2., 
    'reg_lambda':0.0, 
    'random_state':SEED, 
    'n_jobs': 3
}

fit_param = None

try_params = {
    'reg_alpha':[1.0, 1.5, 2.0, 2.5, 3.0]
}

fit_params(train, train_y, ml, default_params, try_params, fit_params=fit_param, seed=SEED, use_eval_set=False)

# %%
ml = model_loader(model_type='xgb')

default_params = {
    'booster':'gbtree', 
    'max_depth':5, 
    'learning_rate':0.1, 
    'n_estimators':100, 
    'gamma':0.0, 
    'min_child_weight':0.001,
    'subsample':1.,  
    'colsample_bytree':1., 
    'reg_alpha':2., 
    'reg_lambda':0.0, 
    'random_state':SEED, 
    'n_jobs': 3
}

fit_param = None

try_params = {
    'reg_lambda':[i/10.0 for i in range(0,11,1)]
}

fit_params(train, train_y, ml, default_params, try_params, fit_params=fit_param, seed=SEED, use_eval_set=False)

# %% [markdown]
# ## Rigde

# %%
ml = model_loader(model_type='rg')

default_params = {
    'alpha': 1.0, 
    'fit_intercept': True, 
    'normalize': False, 
    'copy_X': True, 
    'max_iter': None, 
    'tol': 0.001, 
    'solver':'auto', 
    'random_state': SEED
}

fit_param = None

try_params = {
    'alpha':[1,2,4,8]
}

fit_params(train, train_y, ml, default_params, try_params, fit_params=fit_param, seed=SEED, use_eval_set=False)
# Out:
# {'alpha': 1} train loss: 0.211353, valid loss:0.211762, loss_diff:0.000409
# {'alpha': 1} train loss: 0.211446, valid loss:0.211393, loss_diff:-0.000052
# {'alpha': 1} train loss: 0.211476, valid loss:0.211268, loss_diff:-0.000208
# {'alpha': 1} train loss: 0.211306, valid loss:0.211946, loss_diff:0.000640
# {'alpha': 1} train loss: 0.211565, valid loss:0.210914, loss_diff:-0.000651
# =================>{'alpha': 1} loss:0.211457
# {'alpha': 2} train loss: 0.211354, valid loss:0.211761, loss_diff:0.000407
# {'alpha': 2} train loss: 0.211447, valid loss:0.211392, loss_diff:-0.000055
# {'alpha': 2} train loss: 0.211477, valid loss:0.211268, loss_diff:-0.000210
# {'alpha': 2} train loss: 0.211308, valid loss:0.211945, loss_diff:0.000637
# {'alpha': 2} train loss: 0.211567, valid loss:0.210915, loss_diff:-0.000652
# =================>{'alpha': 2} loss:0.211456
# {'alpha': 4} train loss: 0.211356, valid loss:0.211760, loss_diff:0.000404
# {'alpha': 4} train loss: 0.211449, valid loss:0.211390, loss_diff:-0.000059
# {'alpha': 4} train loss: 0.211479, valid loss:0.211267, loss_diff:-0.000211
# {'alpha': 4} train loss: 0.211309, valid loss:0.211943, loss_diff:0.000634
# {'alpha': 4} train loss: 0.211568, valid loss:0.210916, loss_diff:-0.000652
# =================>{'alpha': 4} loss:0.211455
# {'alpha': 8} train loss: 0.211358, valid loss:0.211759, loss_diff:0.000401
# {'alpha': 8} train loss: 0.211450, valid loss:0.211387, loss_diff:-0.000063
# {'alpha': 8} train loss: 0.211480, valid loss:0.211267, loss_diff:-0.000213
# {'alpha': 8} train loss: 0.211311, valid loss:0.211941, loss_diff:0.000630
# {'alpha': 8} train loss: 0.211569, valid loss:0.210918, loss_diff:-0.000651
# =================>{'alpha': 8} loss:0.211455
# Best params: {'alpha': 8} 	best loss: 0.211454563511
#           param  val_loss_mean  val_loss_std
# 0  {'alpha': 1}       0.211457      0.000365
# 1  {'alpha': 2}       0.211456      0.000365
# 2  {'alpha': 4}       0.211455      0.000364
# 3  {'alpha': 8}       0.211455      0.000363

# %%
ml = model_loader(model_type='rg')

default_params = {
    'alpha': 1.0, 
    'fit_intercept': True, 
    'normalize': False, 
    'copy_X': True, 
    'max_iter': None, 
    'tol': 0.001, 
    'solver':'auto', 
    'random_state': SEED
}

fit_param = None

try_params = {
    'alpha':[0.05, 0.1, 0.5]
}

fit_params(train, train_y, ml, default_params, try_params, fit_params=fit_param, seed=SEED, use_eval_set=False)
# Out:
# {'alpha': 0.05} train loss: 0.211348, valid loss:0.211766, loss_diff:0.000418
# {'alpha': 0.05} train loss: 0.211440, valid loss:0.211399, loss_diff:-0.000042
# {'alpha': 0.05} train loss: 0.211471, valid loss:0.211271, loss_diff:-0.000199
# {'alpha': 0.05} train loss: 0.211301, valid loss:0.211952, loss_diff:0.000651
# {'alpha': 0.05} train loss: 0.211561, valid loss:0.210914, loss_diff:-0.000647
# =================>{'alpha': 0.05} loss:0.211460
# {'alpha': 0.1} train loss: 0.211349, valid loss:0.211765, loss_diff:0.000416
# {'alpha': 0.1} train loss: 0.211441, valid loss:0.211398, loss_diff:-0.000044
# {'alpha': 0.1} train loss: 0.211472, valid loss:0.211270, loss_diff:-0.000201
# {'alpha': 0.1} train loss: 0.211302, valid loss:0.211951, loss_diff:0.000649
# {'alpha': 0.1} train loss: 0.211562, valid loss:0.210914, loss_diff:-0.000648
# =================>{'alpha': 0.1} loss:0.211460
# {'alpha': 0.5} train loss: 0.211352, valid loss:0.211764, loss_diff:0.000412
# {'alpha': 0.5} train loss: 0.211444, valid loss:0.211395, loss_diff:-0.000049
# {'alpha': 0.5} train loss: 0.211475, valid loss:0.211269, loss_diff:-0.000206
# {'alpha': 0.5} train loss: 0.211305, valid loss:0.211948, loss_diff:0.000643
# {'alpha': 0.5} train loss: 0.211564, valid loss:0.210914, loss_diff:-0.000650
# =================>{'alpha': 0.5} loss:0.211458
# Best params: {'alpha': 0.5} 	best loss: 0.211457854448
#              param  val_loss_mean  val_loss_std
# 0  {'alpha': 0.05}       0.211460      0.000367
# 1   {'alpha': 0.1}       0.211460      0.000367
# 2   {'alpha': 0.5}       0.211458      0.000366

# %% [markdown]
# ## Bagging + Ultimate Blending

# %%
seeds = [598754]
config = {
    'lgb_gbdt':{
        'ml': model_loader(model_type='lgb'),
        'param': {
            'boosting_type':'gbdt', 
            'num_leaves':31, 
            'max_depth':5, 
            'learning_rate':0.02, 
            'n_estimators':3000, 
            'min_split_gain':0.4, 
            'min_child_weight':0.001, 
            'min_child_samples':20, 
            'subsample':1.,  
            'colsample_bytree':.9, 
            'reg_alpha':2.0, 
            'reg_lambda':0.2, 
            'random_state':SEED, 
            'n_jobs': 4
        },
        'fit_param': {
            'early_stopping_rounds': 100,
            'verbose': 100,
            'eval_metric': 'rmse'
        }
    },
    'ridge':{
        'ml': model_loader(model_type='rg'),
        'param': {
            'alpha': 8, 
            'fit_intercept': True, 
            'normalize': False, 
            'copy_X': True, 
            'max_iter': None, 
            'tol': 0.001, 
            'solver':'auto', 
            'random_state': SEED
        },
        'fit_param': None
    }
}

# %%
results = []

for k,v in config.items():
    print('Training & bagging: ', k)
    res = {
        'val_oof': np.zeros((len(train_y),)),
        'test_oof': np.zeros((test.shape[0],))
    }
    
    for seed in seeds:
        print('Training seed =', seed)
        if 'random_state' in v['param']:
            v['param']['random_state'] = seed
            
        oof_val_pred, oof_test_pred, _ = get_oof_predictions(train, train_y, test, v['ml'], 
                                                          v['param'], seed=SEED, fit_params=v['fit_param'], 
                                                          use_eval_set= v['fit_param'] is not None)
        
        res['val_oof'] += oof_val_pred
        res['test_oof'] += oof_test_pred
    
    res['val_oof'] /= len(seeds)
    res['test_oof'] /= len(seeds)
    
    results.append(res)
# Out:
# Training & bagging:  lgb_gbdt
# Training seed = 598754
# Training until validation scores don't improve for 100 rounds.
# [100]	train's rmse: 0.212246	valid's rmse: 0.212833
# [200]	train's rmse: 0.211101	valid's rmse: 0.211827
# [300]	train's rmse: 0.210993	valid's rmse: 0.211805
# [400]	train's rmse: 0.210993	valid's rmse: 0.211805
# Early stopping, best iteration is:
# [306]	train's rmse: 0.210993	valid's rmse: 0.211805
# Fold 1 completed.
# Training until validation scores don't improve for 100 rounds.
# [100]	train's rmse: 0.212335	valid's rmse: 0.212475
# [200]	train's rmse: 0.211191	valid's rmse: 0.211454
# [300]	train's rmse: 0.211073	valid's rmse: 0.211437
# Early stopping, best iteration is:
# [272]	train's rmse: 0.211083	valid's rmse: 0.211436
# Fold 2 completed.
# Training until validation scores don't improve for 100 rounds.
# [100]	train's rmse: 0.212379	valid's rmse: 0.212243
# [200]	train's rmse: 0.21123	valid's rmse: 0.211283
# [300]	train's rmse: 0.211122	valid's rmse: 0.211267
# Early stopping, best iteration is:
# [274]	train's rmse: 0.21113	valid's rmse: 0.211267
# Fold 3 completed.
# Training until validation scores don't improve for 100 rounds.
# [100]	train's rmse: 0.212203	valid's rmse: 0.212978
# [200]	train's rmse: 0.21105	valid's rmse: 0.211984
# [300]	train's rmse: 0.210947	valid's rmse: 0.211963
# Early stopping, best iteration is:
# [285]	train's rmse: 0.210951	valid's rmse: 0.211963
# Fold 4 completed.
# Training until validation scores don't improve for 100 rounds.
# [100]	train's rmse: 0.212449	valid's rmse: 0.212013
# [200]	train's rmse: 0.211303	valid's rmse: 0.211003
# [300]	train's rmse: 0.211197	valid's rmse: 0.210986
# Early stopping, best iteration is:
# [298]	train's rmse: 0.211197	valid's rmse: 0.210986
# Fold 5 completed.
# Training & bagging:  ridge
# Training seed = 598754
# Fold 1 completed.
# Fold 2 completed.
# Fold 3 completed.
# Fold 4 completed.
# Fold 5 completed.

# %%
results
# Out:
# [{'test_oof': array([ 0.43012976,  0.11989575,  0.18681456, ...,  0.04950588,
#           0.48096084,  0.11337298]),
#   'val_oof': array([ 0.06805332,  0.05085494,  0.03708395, ...,  0.23074029,
#           0.17018002,  0.13708617])},
#  {'test_oof': array([ 0.43973295,  0.11383719,  0.18686005, ...,  0.05050436,
#           0.49309947,  0.11329323]),
#   'val_oof': array([ 0.07231319,  0.05345392,  0.03705866, ...,  0.22465725,
#           0.16191074,  0.13212057])}]

# %%
import pickle
pickle.dump(results, open('719_meta_oof_result', 'wb'))

# %%
test_df = pd.read_csv("data/test.csv", usecols=['item_id'])
pd.DataFrame(np.clip(results[1]['test_oof'],0,1), 
             index=test_df.item_id,
             columns=['deal_probability']).to_csv('lgb_gbdt_meta_bagging.csv')

# %%
import pickle
results = pickle.load(open('719_meta_oof_result', 'rb'))

# %%
new_train = pd.DataFrame()
new_test = pd.DataFrame()

new_train['f1'] = results[0]['val_oof']
new_train['f2'] = results[1]['val_oof']

new_test['f1'] = results[0]['test_oof']
new_test['f2'] = results[1]['test_oof']

ml = model_loader(model_type='rg')
default_params = {
    'alpha': 1.0, 
    'fit_intercept': True, 
    'normalize': False, 
    'copy_X': True, 
    'max_iter': None, 
    'tol': 0.001, 
    'solver':'auto', 
    'random_state': SEED
}

fit_param = None

try_params = {
    'alpha':[1,2,4,8]
}

fit_params(new_train, train_y, ml, default_params, try_params, fit_params=fit_param, seed=SEED, use_eval_set=False)
# Out:
# {'alpha': 1} train loss: 0.211362, valid loss:0.211747, loss_diff:0.000385
# {'alpha': 1} train loss: 0.211455, valid loss:0.211375, loss_diff:-0.000080
# {'alpha': 1} train loss: 0.211489, valid loss:0.211242, loss_diff:-0.000246
# {'alpha': 1} train loss: 0.211319, valid loss:0.211920, loss_diff:0.000601
# {'alpha': 1} train loss: 0.211571, valid loss:0.210914, loss_diff:-0.000656
# =================>{'alpha': 1} loss:0.211440
# {'alpha': 2} train loss: 0.211362, valid loss:0.211747, loss_diff:0.000385
# {'alpha': 2} train loss: 0.211455, valid loss:0.211375, loss_diff:-0.000080
# {'alpha': 2} train loss: 0.211489, valid loss:0.211242, loss_diff:-0.000247
# {'alpha': 2} train loss: 0.211319, valid loss:0.211920, loss_diff:0.000601
# {'alpha': 2} train loss: 0.211571, valid loss:0.210914, loss_diff:-0.000656
# =================>{'alpha': 2} loss:0.211440
# {'alpha': 4} train loss: 0.211362, valid loss:0.211747, loss_diff:0.000385
# {'alpha': 4} train loss: 0.211455, valid loss:0.211375, loss_diff:-0.000080
# {'alpha': 4} train loss: 0.211489, valid loss:0.211242, loss_diff:-0.000247
# {'alpha': 4} train loss: 0.211319, valid loss:0.211920, loss_diff:0.000601
# {'alpha': 4} train loss: 0.211571, valid loss:0.210915, loss_diff:-0.000656
# =================>{'alpha': 4} loss:0.211440
# {'alpha': 8} train loss: 0.211362, valid loss:0.211748, loss_diff:0.000385
# {'alpha': 8} train loss: 0.211455, valid loss:0.211375, loss_diff:-0.000080
# {'alpha': 8} train loss: 0.211489, valid loss:0.211241, loss_diff:-0.000248
# {'alpha': 8} train loss: 0.211319, valid loss:0.211920, loss_diff:0.000601
# {'alpha': 8} train loss: 0.211571, valid loss:0.210915, loss_diff:-0.000656
# =================>{'alpha': 8} loss:0.211440
# Best params: {'alpha': 4} 	best loss: 0.21143982443
#           param  val_loss_mean  val_loss_std
# 0  {'alpha': 1}        0.21144      0.000359
# 1  {'alpha': 2}        0.21144      0.000359
# 2  {'alpha': 4}        0.21144      0.000359
# 3  {'alpha': 8}        0.21144      0.000359

# %%
new_train[['f1', 'f2']].corr()
# Out:
#           f1        f2
# f1  1.000000  0.998866
# f2  0.998866  1.000000

# %%
default_params = {
    'alpha': 1.0, 
    'fit_intercept': True, 
    'normalize': False, 
    'copy_X': True, 
    'max_iter': None, 
    'tol': 0.001, 
    'solver':'auto', 
    'random_state': SEED
}

oof_val_pred, oof_test_pred, _ = get_oof_predictions(new_train, train_y, new_test, ml, 
                                          default_params, seed=SEED, fit_params=fit_param, 
                                          use_eval_set= False)
# Out:
# Fold 1 completed.
# Fold 2 completed.
# Fold 3 completed.
# Fold 4 completed.
# Fold 5 completed.

# %%
test_df = pd.read_csv("data/test.csv", usecols=['item_id'])
pd.DataFrame(np.clip(oof_test_pred,0,1), 
             index=test_df.item_id,
             columns=['deal_probability']).to_csv('stack_bagging_blending_719_simple.csv')

# %%
pd.DataFrame(np.clip(oof_val_pred,0,1), 
             columns=['deal_probability']).to_csv('stack_bagging_blending_719_simple_val.csv')

# %%
best_blend_test = None
best_score = None
min_w = 0.01
for a in tqdm(np.arange(min_w, 1+min_w-min_w*2, min_w)):
    for b in np.arange(min_w, 1-a+min_w-min_w*1, min_w):
        c = 1-a-b
        combined_res = a*results[0]['val_oof'] + \
                       b*results[1]['val_oof'] + \
                       c*results[2]['val_oof']

        score = clip_rmse(train_y, combined_res)
        if best_score is None or score < best_score:
            best_score = score
            print('best score updated: {:.6f}'.format(best_score), ' coefficient=> {}, {}, {}'.format(a, b, c))
            best_blend_test =  a*results[0]['test_oof'] + \
                               b*results[1]['test_oof'] + \
                               c*results[2]['test_oof']
# Out:
#   0%|                                                                                       | 0/98 [00:00<?, ?it/s]
# best score updated: 0.209618  coefficient=> 0.01, 0.01, 0.98
# best score updated: 0.209601  coefficient=> 0.01, 0.02, 0.97
# best score updated: 0.209584  coefficient=> 0.01, 0.03, 0.96
# best score updated: 0.209568  coefficient=> 0.01, 0.04, 0.95
# best score updated: 0.209552  coefficient=> 0.01, 0.05, 0.94
# best score updated: 0.209536  coefficient=> 0.01, 0.060000000000000005, 0.9299999999999999
# best score updated: 0.209520  coefficient=> 0.01, 0.06999999999999999, 0.92
# best score updated: 0.209504  coefficient=> 0.01, 0.08, 0.91
# best score updated: 0.209489  coefficient=> 0.01, 0.09, 0.9
# best score updated: 0.209473  coefficient=> 0.01, 0.09999999999999999, 0.89
# best score updated: 0.209458  coefficient=> 0.01, 0.11, 0.88
# best score updated: 0.209444  coefficient=> 0.01, 0.12, 0.87
# best score updated: 0.209429  coefficient=> 0.01, 0.13, 0.86
# best score updated: 0.209414  coefficient=> 0.01, 0.14, 0.85
# best score updated: 0.209400  coefficient=> 0.01, 0.15000000000000002, 0.84
# best score updated: 0.209386  coefficient=> 0.01, 0.16, 0.83
# best score updated: 0.209372  coefficient=> 0.01, 0.17, 0.82
# best score updated: 0.209358  coefficient=> 0.01, 0.18000000000000002, 0.8099999999999999
# best score updated: 0.209345  coefficient=> 0.01, 0.19, 0.8
# best score updated: 0.209332  coefficient=> 0.01, 0.2, 0.79
# best score updated: 0.209319  coefficient=> 0.01, 0.21000000000000002, 0.78
# best score updated: 0.209306  coefficient=> 0.01, 0.22, 0.77
# best score updated: 0.209293  coefficient=> 0.01, 0.23, 0.76
# best score updated: 0.209281  coefficient=> 0.01, 0.24000000000000002, 0.75
# best score updated: 0.209268  coefficient=> 0.01, 0.25, 0.74
# best score updated: 0.209256  coefficient=> 0.01, 0.26, 0.73
# best score updated: 0.209244  coefficient=> 0.01, 0.27, 0.72
# best score updated: 0.209233  coefficient=> 0.01, 0.28, 0.71
# best score updated: 0.209221  coefficient=> 0.01, 0.29000000000000004, 0.7
# best score updated: 0.209210  coefficient=> 0.01, 0.3, 0.69
# best score updated: 0.209199  coefficient=> 0.01, 0.31, 0.6799999999999999
# best score updated: 0.209188  coefficient=> 0.01, 0.32, 0.6699999999999999
# best score updated: 0.209178  coefficient=> 0.01, 0.33, 0.6599999999999999
# best score updated: 0.209167  coefficient=> 0.01, 0.34, 0.6499999999999999
# best score updated: 0.209157  coefficient=> 0.01, 0.35000000000000003, 0.6399999999999999
# best score updated: 0.209147  coefficient=> 0.01, 0.36000000000000004, 0.6299999999999999
# best score updated: 0.209137  coefficient=> 0.01, 0.37, 0.62
# best score updated: 0.209128  coefficient=> 0.01, 0.38, 0.61
# best score updated: 0.209118  coefficient=> 0.01, 0.39, 0.6
# best score updated: 0.209109  coefficient=> 0.01, 0.4, 0.59
# best score updated: 0.209100  coefficient=> 0.01, 0.41000000000000003, 0.58
# best score updated: 0.209092  coefficient=> 0.01, 0.42000000000000004, 0.57
# best score updated: 0.209083  coefficient=> 0.01, 0.43, 0.56
# best score updated: 0.209075  coefficient=> 0.01, 0.44, 0.55
# best score updated: 0.209067  coefficient=> 0.01, 0.45, 0.54
# best score updated: 0.209059  coefficient=> 0.01, 0.46, 0.53
# best score updated: 0.209051  coefficient=> 0.01, 0.47000000000000003, 0.52
# best score updated: 0.209044  coefficient=> 0.01, 0.48000000000000004, 0.51
# best score updated: 0.209037  coefficient=> 0.01, 0.49, 0.5
# best score updated: 0.209030  coefficient=> 0.01, 0.5, 0.49
# best score updated: 0.209023  coefficient=> 0.01, 0.51, 0.48
# best score updated: 0.209016  coefficient=> 0.01, 0.52, 0.47
# best score updated: 0.209010  coefficient=> 0.01, 0.53, 0.45999999999999996
# best score updated: 0.209004  coefficient=> 0.01, 0.54, 0.44999999999999996
# best score updated: 0.208998  coefficient=> 0.01, 0.55, 0.43999999999999995
# best score updated: 0.208992  coefficient=> 0.01, 0.56, 0.42999999999999994
# best score updated: 0.208987  coefficient=> 0.01, 0.5700000000000001, 0.41999999999999993
# best score updated: 0.208982  coefficient=> 0.01, 0.5800000000000001, 0.4099999999999999
# best score updated: 0.208977  coefficient=> 0.01, 0.59, 0.4
# best score updated: 0.208972  coefficient=> 0.01, 0.6, 0.39
# best score updated: 0.208967  coefficient=> 0.01, 0.61, 0.38
# best score updated: 0.208963  coefficient=> 0.01, 0.62, 0.37
# best score updated: 0.208959  coefficient=> 0.01, 0.63, 0.36
# best score updated: 0.208955  coefficient=> 0.01, 0.64, 0.35
# best score updated: 0.208951  coefficient=> 0.01, 0.65, 0.33999999999999997
# best score updated: 0.208948  coefficient=> 0.01, 0.66, 0.32999999999999996
# best score updated: 0.208944  coefficient=> 0.01, 0.67, 0.31999999999999995
# best score updated: 0.208941  coefficient=> 0.01, 0.68, 0.30999999999999994
# best score updated: 0.208939  coefficient=> 0.01, 0.6900000000000001, 0.29999999999999993
# best score updated: 0.208936  coefficient=> 0.01, 0.7000000000000001, 0.2899999999999999
# best score updated: 0.208934  coefficient=> 0.01, 0.7100000000000001, 0.2799999999999999
# best score updated: 0.208932  coefficient=> 0.01, 0.72, 0.27
# best score updated: 0.208930  coefficient=> 0.01, 0.73, 0.26
# best score updated: 0.208928  coefficient=> 0.01, 0.74, 0.25
# best score updated: 0.208927  coefficient=> 0.01, 0.75, 0.24
# best score updated: 0.208925  coefficient=> 0.01, 0.76, 0.22999999999999998
# best score updated: 0.208924  coefficient=> 0.01, 0.77, 0.21999999999999997
# best score updated: 0.208924  coefficient=> 0.01, 0.78, 0.20999999999999996
# best score updated: 0.208923  coefficient=> 0.01, 0.79, 0.19999999999999996
# best score updated: 0.208923  coefficient=> 0.01, 0.8, 0.18999999999999995
# best score updated: 0.208923  coefficient=> 0.01, 0.81, 0.17999999999999994
# 100%|██████████████████████████████████████████████████████████████████████████████| 98/98 [03:51<00:00,  2.36s/it]

# %%
best_blend_test = None
best_score = None
min_w = 0.01
for a in np.arange(min_w, 1+min_w-min_w*4, min_w):
    for b in np.arange(min_w, 1-a+min_w-min_w*3, min_w):
        for c in np.arange(min_w, 1-a-b+min_w-min_w*2, min_w):
            for d in np.arange(min_w, 1-a-b-c+min_w-min_w*1, min_w):
                e = 1-a-b-c-d
                combined_res = a*results[0]['val_oof'] + \
                               b*results[1]['val_oof'] + \
                               c*results[2]['val_oof'] + \
                               d*results[3]['val_oof'] + \ 
                               e*results[4]['val_oof']
                
                score = clip_rmse(train_y, combined_res)
                if best_score is None or score < best_score:
                    best_score = score
                    print('best score updated:', best_score)
                    best_blend_test =  a*results[0]['test_oof'] + \
                                       b*results[1]['test_oof'] + \
                                       c*results[2]['test_oof'] + \
                                       d*results[3]['test_oof'] + \ 
                                       e*results[4]['test_oof']

# %%
test_df = pd.read_csv("data/test.csv", usecols=['item_id'])
pd.DataFrame(np.clip(best_blend_test,0,1), 
             index=test_df.item_id,
             columns=['deal_probability']).to_csv('stack_bagging_blend_no_xgb_meta.csv')
