# %%
import pandas as pd
import numpy as np
import gc; gc.enable()

# %%
usecols = ['activation_date',
           'item_id',
           'region',
           'city',
           'parent_category_name',
           'category_name',
           'param_1',
           'param_2',
           'param_3',
           'title',
           'description',
           'price', 
           'item_seq_number']

# %%
ad_period_features = pd.read_csv('ad_period_features.csv', usecols=['item_id', 'activation_date', 'duration_3'], parse_dates=['activation_date'])
ad_period_features.head(3)
# Out:
#         item_id activation_date  duration_3
# 0  0fceba64da0d      2017-01-01           2
# 1  e06329e1ce56      2017-01-01           2
# 2  0d3f55aa2786      2017-01-01           6

# %%
ad_period_features.loc[:, 'ad_total_count'] = \
    ad_period_features['item_id'].map(ad_period_features.groupby('item_id')['duration_3'].count())
    
ad_period_features.loc[:, 'days_up'] = \
    ad_period_features['item_id'].map(ad_period_features.groupby('item_id')['duration_3'].sum())

# %%
ad_period_features.drop_duplicates(['item_id'],inplace=True)

# %%
ad_period_features = ad_period_features.drop(['activation_date'], axis=1).set_index('item_id')
ad_period_features.head(3)
# Out:
#               duration_3  ad_total_count  days_up
# item_id
# 0fceba64da0d           2               2       12
# e06329e1ce56           2               1        2
# 0d3f55aa2786           6               1        6

# %%
days_up_mean = ad_period_features.days_up.mean()
count_mean = ad_period_features.ad_total_count.mean()
days_up_mean, count_mean
# Out:
# (12.333354017369892, 1.7425203000067666)

# %%
def process_chunk(df):
    print('Original data shape', df.shape)
    df = df.loc[~df.activation_date.isnull(),:].reset_index(drop=True)
    df = df.loc[~df.item_id.isnull(),:].reset_index(drop=True)
    print('New data shape', df.shape)
    
    for c in ['region', 'city', 'parent_category_name', 'category_name', 'title', 'description', 'param_1', 'param_2', 'param_3']:
        df.loc[:, c] = df[c].fillna('unknown')
    
    df.loc[:, 'city'] = df['region'] + '_' + df['city']
    
    for c in ['price', 'item_seq_number']:
        df.loc[:, c] = df[c].fillna(-1)
        
    for col in ['title', 'description']:
        df[col+'_len'] = df[col].apply(len)
        df[col+'_word_cnt'] = df[col].apply(lambda x: len(x.split()) if x != 'unknown' else 0)
        df[col+'_unique_word_cnt'] = df[col].apply(lambda x: len(set(x.split())) if x != 'unknown' else 0)
        df[col+'_unqiue_percent'] = df[col+'_unique_word_cnt'] / df[col+'_word_cnt'] * 100.
        
    df.loc[:, 'days_up'] = df['item_id'].map(ad_period_features['days_up']).fillna(days_up_mean)
    df.loc[:, 'ad_total_count'] = df['item_id'].map(ad_period_features['ad_total_count']).fillna(count_mean)
    
    df.drop(['title', 'description', 'activation_date', 'item_id'], axis=1, inplace=True)
    
    return df

# %%
files = [
    'data/train.csv', 'data/test.csv', 'data/train_active.csv', 'data/test_active.csv'
]
all_df = None

for f in files:
    print('Processing file:', f)
    for chunk in pd.read_csv(f, usecols=usecols, chunksize=2000000, parse_dates=['activation_date']):
        if f == 'data/train.csv':
            chunk = chunk.sort_values('activation_date').reset_index(drop=True)
            print('Index reset!')
            
        chunk = process_chunk(chunk)
        gc.collect()
        if all_df is None:
            all_df = chunk
        else:
            all_df = pd.concat([all_df, chunk]).reset_index(drop=True)
            del chunk; gc.collect()
# Out:
# Processing file: data/train.csv
# Index reset!
# Original data shape (1503424, 13)
# New data shape (1503424, 13)
# Processing file: data/test.csv
# Original data shape (508438, 13)
# New data shape (508438, 13)
# Processing file: data/train_active.csv
# Original data shape (2000000, 13)
# New data shape (1982514, 13)
# Original data shape (2000000, 13)
# New data shape (1982505, 13)
# Original data shape (2000000, 13)
# New data shape (1982159, 13)
# Original data shape (2000000, 13)
# New data shape (1982337, 13)
# Original data shape (2000000, 13)
# New data shape (1982509, 13)
# Original data shape (2000000, 13)
# New data shape (1982352, 13)
# Original data shape (2000000, 13)
# New data shape (1982461, 13)
# Original data shape (129821, 13)
# New data shape (128661, 13)
# Processing file: data/test_active.csv
# Original data shape (2000000, 13)
# New data shape (1982305, 13)
# Original data shape (2000000, 13)
# New data shape (1981914, 13)
# Original data shape (2000000, 13)
# New data shape (1982109, 13)
# Original data shape (2000000, 13)
# New data shape (1982426, 13)
# Original data shape (2000000, 13)
# New data shape (1982131, 13)
# Original data shape (2000000, 13)
# New data shape (1982012, 13)
# Original data shape (824068, 13)
# New data shape (816653, 13)

# %%
all_df.shape
# Out:
# (28726910, 19)

# %%
all_df.isnull().sum()
# Out:
# region                               0
# city                                 0
# parent_category_name                 0
# category_name                        0
# param_1                              0
# param_2                              0
# param_3                              0
# price                                0
# item_seq_number                      0
# title_len                            0
# title_word_cnt                       0
# title_unique_word_cnt                0
# title_unqiue_percent              1020
# description_len                      0
# description_word_cnt                 0
# description_unique_word_cnt          0
# description_unqiue_percent     1141141
# days_up                              0
# ad_total_count                       0
# dtype: int64

# %%
all_df.loc[:, 'title_unqiue_percent'] = all_df['title_unqiue_percent'].fillna(0.)
all_df.loc[:, 'description_unqiue_percent'] = all_df['description_unqiue_percent'].fillna(0.)

# %%
all_df
# Out:
#                            region                                   city  \
# 0               Самарская область               Самарская область_Самара
# 1               Иркутская область               Иркутская область_Братск
# 2                   Пермский край              Пермский край_Краснокамск
# 3            Оренбургская область          Оренбургская область_Оренбург
# 4             Ярославская область          Ярославская область_Ярославль
# 5               Иркутская область              Иркутская область_Иркутск
# 6               Иркутская область       Иркутская область_Усть-Ордынский
# 7                Тульская область                Тульская область_Теплое
# 8            Оренбургская область           Оренбургская область_Бузулук
# 9                    Башкортостан             Башкортостан_Нижнетроицкий
# 10            Челябинская область          Челябинская область_Челябинск
# 11           Свердловская область      Свердловская область_Екатеринбург
# 12            Челябинская область          Челябинская область_Челябинск
# 13             Краснодарский край       Краснодарский край_Ленинградская
# 14            Саратовская область            Саратовская область_Саратов
# 15            Кемеровская область           Кемеровская область_Кемерово
# 16                      Татарстан             Татарстан_Набережные Челны
# 17                  Пермский край                    Пермский край_Пермь
# 18           Свердловская область             Свердловская область_Серов
# 19                   Башкортостан                Башкортостан_Нефтекамск
# 20                      Татарстан                       Татарстан_Казань
# 21             Ростовская область      Ростовская область_Ростов-на-Дону
# 22             Краснодарский край             Краснодарский край_Армавир
# 23              Самарская область               Самарская область_Самара
# 24              Красноярский край           Красноярский край_Красноярск
# 25           Оренбургская область        Оренбургская область_Новотроицк
# 26                 Омская область                    Омская область_Омск
# 27          Новосибирская область      Новосибирская область_Новосибирск
# 28          Волгоградская область         Волгоградская область_Волжский
# 29          Волгоградская область        Волгоградская область_Волгоград
# ...                           ...                                    ...
# 28726880     Владимирская область            Владимирская область_Ковров
# 28726881     Свердловская область      Свердловская область_Екатеринбург
# 28726882     Белгородская область      Белгородская область_Старый Оскол
# 28726883                Татарстан                       Татарстан_Казань
# 28726884     Свердловская область      Свердловская область_Екатеринбург
# 28726885      Ставропольский край  Ставропольский край_Новоалександровск
# 28726886    Новосибирская область      Новосибирская область_Новосибирск
# 28726887           Алтайский край                 Алтайский край_Барнаул
# 28726888       Ростовская область          Ростовская область_Волгодонск
# 28726889        Красноярский край           Красноярский край_Красноярск
# 28726890      Воронежская область            Воронежская область_Воронеж
# 28726891    Нижегородская область  Нижегородская область_Нижний Новгород
# 28726892     Свердловская область      Свердловская область_Екатеринбург
# 28726893    Волгоградская область        Волгоградская область_Волгоград
# 28726894      Кемеровская область        Кемеровская область_Прокопьевск
# 28726895    Нижегородская область  Нижегородская область_Нижний Новгород
# 28726896    Новосибирская область      Новосибирская область_Новосибирск
# 28726897    Нижегородская область  Нижегородская область_Нижний Новгород
# 28726898                Татарстан                       Татарстан_Казань
# 28726899           Алтайский край                 Алтайский край_Барнаул
# 28726900        Красноярский край           Красноярский край_Красноярск
# 28726901                Татарстан                      Татарстан_Елабуга
# 28726902      Саратовская область            Саратовская область_Саратов
# 28726903      Ставропольский край          Ставропольский край_Пятигорск
# 28726904      Челябинская область            Челябинская область_Коркино
# 28726905  Калининградская область    Калининградская область_Калининград
# 28726906       Краснодарский край           Краснодарский край_Краснодар
# 28726907      Саратовская область            Саратовская область_Энгельс
# 28726908       Ростовская область      Ростовская область_Ростов-на-Дону
# 28726909             Башкортостан                       Башкортостан_Уфа
#
#          parent_category_name               category_name  \
# 0                 Личные вещи      Детская одежда и обувь
# 1         Бытовая электроника                    Телефоны
# 2                 Личные вещи   Одежда, обувь, аксессуары
# 3                    Животные         Товары для животных
# 4                 Личные вещи   Одежда, обувь, аксессуары
# 5                 Личные вещи   Одежда, обувь, аксессуары
# 6         Бытовая электроника                    Телефоны
# 7                Недвижимость                    Квартиры
# 8                    Животные                       Кошки
# 9             Для дома и дачи            Продукты питания
# 10                Личные вещи  Товары для детей и игрушки
# 11                Личные вещи  Товары для детей и игрушки
# 12                Личные вещи   Одежда, обувь, аксессуары
# 13               Недвижимость                    Квартиры
# 14                     Услуги           Предложение услуг
# 15                Личные вещи   Одежда, обувь, аксессуары
# 16                Личные вещи      Детская одежда и обувь
# 17                Личные вещи   Одежда, обувь, аксессуары
# 18        Бытовая электроника                    Телефоны
# 19                Личные вещи   Одежда, обувь, аксессуары
# 20               Недвижимость           Земельные участки
# 21                Личные вещи  Товары для детей и игрушки
# 22                Личные вещи      Детская одежда и обувь
# 28726881                     Аксессуары                         unknown
# 28726882                          Такса                         unknown
# 28726883                  Для мальчиков                  Верхняя одежда
# 28726884  Предметы интерьера, искусство                         unknown
# 28726885                         Продам                             Дом
# 28726886                      Мотоциклы                      Спортивные
# 28726887                 Женская одежда                Свадебные платья
# 28726888                 Женская одежда                           Брюки
# 28726889       Кровати, диваны и кресла                         unknown
# 28726890          Велосипеды и самокаты                         unknown
# 28726891                 Мужская одежда                  Верхняя одежда
# 28726892                        unknown                         unknown
# 28726893                Детские коляски                         unknown
# 28726894                  Для мальчиков                        Трикотаж
# 28726895                        unknown                         unknown
# 28726896                 Женская одежда                           Обувь
# 28726897                  Для мальчиков                  Верхняя одежда
# 28726898                 Женская одежда                           Обувь
# 28726899                           Сдам              На длительный срок
# 28726900                    Для девочек                          Другое
# 28726901                          Сниму              На длительный срок
# 28726902                        Игрушки                         unknown
# 28726903                 Женская одежда                           Обувь
# 28726904           Приборы и аксессуары                         unknown
# 28726905                Музыка и фильмы                         unknown
# 28726906          Ремонт, строительство  Строительство домов, коттеджей
# 28726907                   Единоборства                         unknown
# 28726908                  Комплектующие              Оперативная память
# 28726909                 Женская одежда                           Обувь
#
#                         param_3     price  item_seq_number  title_len  \
# 0           86-92 см (1-2 года)     500.0             12.0         17
# 1                       unknown     100.0              5.0         19
# 2                     44–46 (M)    1500.0             32.0         22
# 3                       unknown     350.0             17.0         24
# 4                       unknown    1500.0              7.0         24
# 5                     46–48 (L)     800.0              4.0          4
# 6                       unknown     399.0          71051.0         20
# 7                      Вторичка  950000.0              7.0         28
# 8                       unknown      -1.0             19.0         13
# 9                       unknown       1.0              5.0          8
# 10                      unknown    1000.0             32.0         26
# 11                      unknown    6500.0           4136.0         11
# 12                   40–42 (XS)     450.0             28.0         50
# 13                     Вторичка      -1.0             39.0         30
# 14                      unknown     200.0             31.0         33
# 15                   48–50 (XL)    4000.0              2.0         15
# 16                           25     200.0             36.0          6
# 17                           36    1000.0             12.0         15
# 18                      unknown     150.0             19.0         33
# 19                      unknown     500.0             41.0          5
# 20                      unknown  750000.0             28.0         26
# 21                      unknown     500.0             70.0         22
# 22        134-140 см (8-10 лет)     400.0             24.0         12
# 23          86-92 см (1-2 года)    1000.0              3.0         19
# 24          74-80 см (7-12 мес)    1500.0             25.0         23
# 25                      unknown    1000.0              6.0         11
# 26                      unknown     900.0            313.0         24
# 27                    42–44 (S)     450.0             28.0         15
# 28                      unknown    4000.0              1.0         24
# 29                      unknown    6000.0             48.0         34
# ...                         ...       ...              ...        ...
# 28726880                 Granta  420000.0             92.0         17
# 28726881                unknown     550.0             12.0         17
# 28726882                unknown     500.0              6.0          5
# 28726883    74-80 см (7-12 мес)     900.0             13.0         23
# 28726884                unknown   15000.0             14.0         20
# 28726885                unknown  800000.0              8.0         30
# 28726886                unknown  250000.0              3.0         20
# 28726887              42–44 (S)    5000.0            183.0         29
# 28726888              42–44 (S)    1500.0             29.0         31
# 28726889                unknown   38000.0             75.0         26
# 28726890                unknown    1800.0              8.0         32
# 28726891            52–54 (XXL)    2900.0             74.0         26
# 28726892                unknown     350.0             83.0          5
# 28726893                unknown    2800.0             35.0          7
# 28726894   110-116 см (4-6 лет)     400.0             35.0          5
# 28726895                unknown    4000.0             41.0         28
# 28726896                     39    1000.0             85.0          6
# 28726897   98-104 см (2-4 года)     500.0            134.0         13
# 28726898                     39     550.0             53.0         14
# 28726899                      1    8500.0             18.0         28
# 28726900                unknown     120.0             66.0          6
# 28726901                      1    7000.0              2.0         18
# 28726902                unknown     350.0             19.0         25
# 28726903                     40    1200.0            168.0         13
# 28726904                unknown     900.0             38.0          7
# 28726905                unknown     100.0             11.0          5
# 28726906                unknown     500.0             24.0         26
# 28726907                unknown    1000.0             33.0         31
# 28726908                unknown     500.0            103.0         14
# 28726909                     37    1000.0             60.0         15
#
#           title_word_cnt  title_unique_word_cnt  title_unqiue_percent  \
# 0                      2                      2                 100.0
# 1                      4                      4                 100.0
# 2                      3                      3                 100.0
# 3                      4                      4                 100.0
# 4                      3                      3                 100.0
# 5                      1                      1                 100.0
# 6                      2                      2                 100.0
# 7                      6                      6                 100.0
# 8                      2                      2                 100.0
# 9                      1                      1                 100.0
# 10                     6                      6                 100.0
# 11                     2                      2                 100.0
# 12                     7                      7                 100.0
# 13                     6                      6                 100.0
# 14                     4                      4                 100.0
# 15                     2                      2                 100.0
# 16                     1                      1                 100.0
# 17                     2                      2                 100.0
# 18                     6                      6                 100.0
# 19                     1                      1                 100.0
# 20                     5                      5                 100.0
# 21                     3                      3                 100.0
# 22                     2                      2                 100.0
# 23                     2                      2                 100.0
# 24                     3                      3                 100.0
# 25                     1                      1                 100.0
# 26                     3                      3                 100.0
# 27                     3                      3                 100.0
# 28                     4                      4                 100.0
# 29                     6                      6                 100.0
# ...                  ...                    ...                   ...
# 28726880               3                      3                 100.0
# 28726881               3                      3                 100.0
# 28726882               1                      1                 100.0
# 28726883               3                      3                 100.0
# 28726884               3                      3                 100.0
# 28726885               7                      7                 100.0
# 28726886               4                      4                 100.0
# 28726887               4                      4                 100.0
# 28726888               5                      5                 100.0
# 28726889               4                      4                 100.0
# 28726890               4                      4                 100.0
# 28726891               5                      5                 100.0
# 28726892               1                      1                 100.0
# 28726893               1                      1                 100.0
# 28726894               1                      1                 100.0
# 28726895               4                      4                 100.0
# 28726896               1                      1                 100.0
# 28726897               2                      2                 100.0
# 28726898               2                      2                 100.0
# 28726899               6                      6                 100.0
# 28726900               1                      1                 100.0
# 28726901               3                      3                 100.0
# 28726902               3                      3                 100.0
# 28726903               2                      2                 100.0
# 28726904               1                      1                 100.0
# 28726905               1                      1                 100.0
# 28726906               3                      3                 100.0
# 28726907               4                      4                 100.0
# 28726908               3                      3                 100.0
# 28726909               2                      2                 100.0
#
#           description_len  description_word_cnt  description_unique_word_cnt  \
# 0                      28                     4                            4
# 1                      15                     2                            2
# 2                       7                     0                            0
# 3                     112                    18                           17
# 4                      60                    10                           10
# 5                       7                     0                            0
# 28726886                  100.000000  19.000000         2.00000
# 28726887                  100.000000  19.000000         2.00000
# 28726888                  100.000000  14.000000         2.00000
# 28726889                   62.430939  18.000000         3.00000
# 28726890                   95.652174   6.000000         1.00000
# 28726891                  100.000000  15.000000         3.00000
# 28726892                  100.000000  18.000000         3.00000
# 28726893                   90.909091  19.000000         2.00000
# 28726894                  100.000000  19.000000         2.00000
# 28726895                   94.444444   6.000000         1.00000
# 28726896                  100.000000  15.000000         4.00000
# 28726897                   90.000000  16.000000         4.00000
# 28726898                   95.238095  19.000000         2.00000
# 28726899                  100.000000  15.000000         4.00000
# 28726900                  100.000000  16.000000         3.00000
# 28726901                   95.238095   1.000000         1.00000
# 28726902                  100.000000  17.000000         4.00000
# 28726903                  100.000000  18.000000         2.00000
# 28726904                   90.000000   2.000000         1.00000
# 28726905                    0.000000  18.000000         3.00000
# 28726906                  100.000000   7.000000         2.00000
# 28726907                  100.000000  19.000000         2.00000
# 28726908                  100.000000   6.000000         1.00000
# 28726909                  100.000000  12.000000         3.00000
#
# [28726910 rows x 19 columns]

# %%
from sklearn.preprocessing import LabelEncoder
for feature in ['region', 'city', 'parent_category_name', 'category_name', 'param_1', 'param_2', 'param_3']:
    print(f'Transforming {feature}...')
    encoder = LabelEncoder()
    all_df.loc[:, feature] = encoder.fit_transform(all_df[feature].astype(str))
# Out:
# Transforming region...
# Transforming city...
# Transforming parent_category_name...
# Transforming category_name...
# Transforming param_1...
# Transforming param_2...
# Transforming param_3...

# %%
all_df.days_up.value_counts()
# Out:
# 19.000000    6569380
# 18.000000    3793028
# 6.000000     3104271
# 13.000000    2988521
# 12.333354    2011950
# 15.000000    1743718
# 17.000000    1642904
# 14.000000    1149528
# 16.000000     938920
# 12.000000     639050
# 11.000000     489844
# 7.000000      458120
# 8.000000      445642
# 1.000000      440074
# 10.000000     425869
# 9.000000      418766
# 2.000000      376037
# 5.000000      373865
# 3.000000      358097
# 4.000000      353788
# 0.000000        5538
# Name: days_up, dtype: int64

# %%
all_df.ad_total_count.value_counts()
# Out:
# 2.00000     11652555
# 1.00000      8304201
# 3.00000      5972047
# 1.74252      2011950
# 4.00000       781265
# 5.00000         3516
# 6.00000          465
# 13.00000         329
# 14.00000         182
# 9.00000          128
# 7.00000          104
# 8.00000           58
# 12.00000          33
# 15.00000          30
# 10.00000          25
# 11.00000          16
# 19.00000           4
# 16.00000           2
# Name: ad_total_count, dtype: int64

# %%
train_len = pd.read_csv('data/train.csv', usecols=['region']).shape[0]
test_len = pd.read_csv('data/test.csv', usecols=['region']).shape[0]
train_len, test_len
# Out:
# (1503424, 508438)

# %%
import pickle

# %%
with open('data/active_test_train.pickle', 'wb') as handle:
    pickle.dump(all_df.loc[:train_len-1,:], handle)
    
with open('data/active_test_test.pickle', 'wb') as handle:
    pickle.dump(all_df.loc[train_len:train_len+test_len-1,:].reset_index(drop=True), handle)
    
with open('data/active_train.pickle', 'wb') as handle:
    pickle.dump(all_df.loc[train_len+test_len:,:].reset_index(drop=True), handle)
